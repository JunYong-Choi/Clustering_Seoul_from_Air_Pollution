# %% [markdown]
# <font color="#CC3D3D"><p>
# # ***다변량 Team Project***

# %% [markdown]
# - **`PROBLEM`**: 서울시 대기오염의 취약층을 찾아라!!
# - **`INPUT`**: 최근 3년 서울시 대기오염 데이터(`daegi_20, 21, 22`)
# - **`OUTPUT`**: 위 데이터를 이용하여 대기오염이 심한 지역에 해결책 제안

# %% [markdown]
# * [1. Read Data](#1.-Read-Data)
# * [2. Data Cleansing & Feature Engineering](#2.-Data-Cleansing-&-Feature-Engineering)
# * [3. Analysis](#3.-Analysis)
# * [4. Final Analysis and Troubleshooting](#4.-Final-Analysis-and-Troubleshooting)

# %% [markdown]
# ##### Imports

# %%
import pandas as pd
import numpy as np
import os
from datetime import date, time

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.spatial.distance import pdist, squareform

import matplotlib
import platform
from matplotlib import font_manager, rc

# %% [markdown]
# # 1. Read Data
#
# **서울시 일별 평균 대기오염도 정보(최근 3년 데이터)**
# 출처 : 서울열린데이터광장 (https://data.seoul.go.kr/dataList/OA-2218/S/1/datasetView.do#AXexec)

# %% [markdown]
# ![art_15457372306787_7754fa.png](attachment:art_15457372306787_7754fa.png)

# %%
daegi_20 = pd.read_csv(os.path.abspath("../프로젝트/Data")+"/일별평균대기오염도_2020.csv" , encoding = 'cp949')
daegi_21 = pd.read_csv(os.path.abspath("../프로젝트/Data")+"/일별평균대기오염도_2021.csv" , encoding = 'cp949')
daegi_22 = pd.read_csv(os.path.abspath("../프로젝트/Data")+"/일별평균대기오염도_2022.csv" , encoding = 'cp949')

# %%
daegi_20
# Out:
#            측정일시  측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스농도(ppm)  \
# 0      20200101   강남구         0.037      0.003           0.7         0.003
# 1      20200101  강남대로         0.036      0.003           1.1         0.004
# 2      20200101   강동구         0.036      0.004           0.6         0.003
# 3      20200101  강변북로         0.042      0.003           0.8         0.004
# 4      20200101   강북구         0.045      0.004           0.7         0.003
# ...         ...   ...           ...        ...           ...           ...
# 18295  20201231  청계천로         0.020      0.019           0.5         0.003
# 18296  20201231  한강대로         0.026      0.017           0.5         0.003
# 18297  20201231    행주         0.013      0.026           0.6         0.003
# 18298  20201231   홍릉로         0.027      0.014           0.5         0.004
# 18299  20201231   화랑로         0.026      0.010           0.3         0.003
#
#        미세먼지농도(㎍/㎥)  초미세먼지농도(㎍/㎥)
# 0             31.0          23.0
# 1             36.0          20.0
# 2             37.0          28.0
# 3             40.0          26.0
# 4             41.0          27.0
# ...            ...           ...
# 18295         25.0          15.0
# 18296         29.0          11.0
# 18297         24.0          11.0
# 18298          5.0           3.0
# 18299         30.0          13.0
#
# [18300 rows x 8 columns]

# %% [markdown]
# # 2. Data Cleansing & Feature Engineering

# %%
daegi_data = pd.concat([daegi_20, daegi_21, daegi_22], axis=0).sort_values(by="측정일시").reset_index(drop=True)

# %% [markdown]
# ## ***Data Cleansing***

# %% [markdown]
# ### ***대기Data 전처리***

# %%
daegi_data.head(3)
# Out:
#        측정일시 측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스농도(ppm)  \
# 0  20200101  강남구         0.037      0.003           0.7         0.003
# 1  20200101  성북구         0.044      0.004           0.9         0.003
# 2  20200101   세곡         0.015      0.005           0.8         0.004
#
#    미세먼지농도(㎍/㎥)  초미세먼지농도(㎍/㎥)  아황산가스(ppm)  미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)
# 0         31.0          23.0         NaN        NaN         NaN
# 1         33.0          21.0         NaN        NaN         NaN
# 2         27.0          18.0         NaN        NaN         NaN

# %%
# 2020,2021 아황산가스농도(ppm) -> 2022 아황산가스(ppm)붙이기
# 2020,2021 미세먼지농도(㎍/㎥) -> 2022 미세먼지(㎍/㎥)붙이기
# 2020,2021 초미세먼지농도(㎍/㎥) -> 2022 초미세먼지(㎍/㎥)붙이기

daegi_data['아황산가스농도(ppm)'] = daegi_data['아황산가스농도(ppm)'].fillna(daegi_data['아황산가스(ppm)'])
daegi_data['미세먼지농도(㎍/㎥)'] = daegi_data['미세먼지농도(㎍/㎥)'].fillna(daegi_data['미세먼지(㎍/㎥)'])
daegi_data['초미세먼지농도(㎍/㎥)'] = daegi_data['초미세먼지농도(㎍/㎥)'].fillna(daegi_data['초미세먼지(㎍/㎥)'])
daegi_data = daegi_data.iloc[:,:-3]
daegi_data
# Out:
#            측정일시  측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스농도(ppm)  \
# 0      20200101   강남구         0.037      0.003           0.7         0.003
# 1      20200101   성북구         0.044      0.004           0.9         0.003
# 2      20200101    세곡         0.015      0.005           0.8         0.004
# 3      20200101   송파구         0.037      0.003           0.7         0.003
# 4      20200101  시흥대로         0.044      0.003           0.7         0.004
# ...         ...   ...           ...        ...           ...           ...
# 51745  20221031   송파구         0.030      0.019           0.4         0.003
# 51746  20221031    세곡         0.029      0.008           1.0         0.003
# 51747  20221031   성북구         0.029      0.022           0.5         0.002
# 51748  20221031   정릉로         0.034      0.015           0.5         0.003
# 51749  20221031   용산구         0.026      0.022           0.4         0.003
#
#        미세먼지농도(㎍/㎥)  초미세먼지농도(㎍/㎥)
# 0             31.0          23.0
# 1             33.0          21.0
# 2             27.0          18.0
# 3             32.0          22.0
# 4             33.0          24.0
# ...            ...           ...
# 51745         26.0          14.0
# 51746         26.0          12.0
# 51747         24.0          14.0
# 51748         27.0          14.0
# 51749         25.0          14.0
#
# [51750 rows x 8 columns]

# %%
daegi_data.isnull().sum()
# Out:
# 측정일시              0
# 측정소명              0
# 이산화질소농도(ppm)    752
# 오존농도(ppm)       586
# 일산화탄소농도(ppm)    783
# 아황산가스농도(ppm)    655
# 미세먼지농도(㎍/㎥)     896
# 초미세먼지농도(㎍/㎥)    876
# dtype: int64

# %% [markdown]
# ### ***결측치 처리***

# %%
daegi_data.측정소명.unique()
# Out:
# array(['강남구', '성북구', '세곡', '송파구', '시흥대로', '신촌로', '양천구', '영등포구', '영등포로',
#        '올림픽공원', '용산구', '성동구', '자연사박물관', '종로', '종로구', '중구', '중랑구', '천호대로',
#        '청계천로', '한강대로', '행주', '홍릉로', '화랑로', '정릉로', '서초구', '은평구', '서대문구',
#        '서울숲', '강남대로', '강동구', '강변북로', '강북구', '강서구', '공항대로', '관악산', '광진구',
#        '구로구', '궁동', '관악구', '마포아트센터', '남산', '노원구', '도봉구', '도산대로', '동대문구',
#        '동작구', '동작대로', '마포구', '금천구', '북한산', '항동'], dtype=object)

# %%
# 이전 값으로 결측치 채우기 (반복문으로 측정소별 변수 생성)
daegi_list = []
for i in daegi_data.측정소명.unique():
    globals()[f"dae_{i}"] = daegi_data.query('측정소명==@i').fillna(method='ffill').fillna(method='bfill')
    daegi_list.append(f'dae_{i}') # 대기변수명 리스트

# %%
daegi_list
# Out:
# ['dae_강남구',
#  'dae_성북구',
#  'dae_세곡',
#  'dae_송파구',
#  'dae_시흥대로',
#  'dae_신촌로',
#  'dae_양천구',
#  'dae_영등포구',
#  'dae_영등포로',
#  'dae_올림픽공원',
#  'dae_용산구',
#  'dae_성동구',
#  'dae_자연사박물관',
#  'dae_종로',
#  'dae_종로구',
#  'dae_중구',
#  'dae_중랑구',
#  'dae_천호대로',
#  'dae_청계천로',
#  'dae_한강대로',
#  'dae_행주',
#  'dae_홍릉로',
#  'dae_화랑로',
#  'dae_정릉로',
#  'dae_서초구',
#  'dae_은평구',
#  'dae_서대문구',
#  'dae_서울숲',
#  'dae_강남대로',
#  'dae_강동구',
#  'dae_강변북로',
#  'dae_강북구',
#  'dae_강서구',
#  'dae_공항대로',
#  'dae_관악산',
#  'dae_광진구',
#  'dae_구로구',
#  'dae_궁동',
#  'dae_관악구',
#  'dae_마포아트센터',
#  'dae_남산',
#  'dae_노원구',
#  'dae_도봉구',
#  'dae_도산대로',
#  'dae_동대문구',
#  'dae_동작구',
#  'dae_동작대로',
#  'dae_마포구',
#  'dae_금천구',
#  'dae_북한산',
#  'dae_항동']

# %%
# 합쳐줄 데이터
daegi_data2 = dae_강남구.copy()

# %%
for i in daegi_list[1:]:
    daegi_data2 = pd.concat([daegi_data2,eval(i)], axis=0).sort_index()

# %%
daegi_data2.head()
# Out:
#        측정일시  측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스농도(ppm)  \
# 0  20200101   강남구         0.037      0.003           0.7         0.003
# 1  20200101   성북구         0.044      0.004           0.9         0.003
# 2  20200101    세곡         0.015      0.005           0.8         0.004
# 3  20200101   송파구         0.037      0.003           0.7         0.003
# 4  20200101  시흥대로         0.044      0.003           0.7         0.004
#
#    미세먼지농도(㎍/㎥)  초미세먼지농도(㎍/㎥)
# 0         31.0          23.0
# 1         33.0          21.0
# 2         27.0          18.0
# 3         32.0          22.0
# 4         33.0          24.0

# %%
daegi_data2.isnull().sum()
# Out:
# 측정일시            0
# 측정소명            0
# 이산화질소농도(ppm)    0
# 오존농도(ppm)       0
# 일산화탄소농도(ppm)    0
# 아황산가스농도(ppm)    0
# 미세먼지농도(㎍/㎥)     0
# 초미세먼지농도(㎍/㎥)    0
# dtype: int64

# %%
daegi_data2.to_csv('대기환경데이터.csv', index=False)

# %% [markdown]
# ## ***Feature Engineering***

# %%
data = pd.read_csv("./대기환경데이터.csv" , encoding = 'UTF-8')

# %%
data.head(3)
# Out:
#        측정일시 측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스농도(ppm)  \
# 0  20200101  강남구         0.037      0.003           0.7         0.003
# 1  20200101  성북구         0.044      0.004           0.9         0.003
# 2  20200101   세곡         0.015      0.005           0.8         0.004
#
#    미세먼지농도(㎍/㎥)  초미세먼지농도(㎍/㎥)
# 0         31.0          23.0
# 1         33.0          21.0
# 2         27.0          18.0

# %%
# Data 년, 월, 일 생성

data['year'] = data['측정일시'].apply(lambda x: int(str(x)[:4]))
data['month'] = data['측정일시'].apply(lambda x: int(str(x)[4:6]))
data['day'] = data['측정일시'].apply(lambda x: int(str(x)[6:]))
data['datetime'] = data['측정일시'].apply(lambda x: (str(x)))
data['datetime'] = pd.to_datetime(data['datetime'], format = '%Y%m%d')

# %%
# 계절
data["season"] = data['month'].apply(lambda x : 'SPRING' if (x>=3) and (x<=5)
                                                  else 'SUMMER' if (x>=6) and (x<=8)
                                                  else 'FALL' if (x>=9) and (x<=11)
                                                  else 'WINTER')

# %%
# 상하반기

data['상하반기'] = data['month'].apply(lambda x : '상반기' if x in [1,2,3,4,5,6] else '하반기')

# %%
# 요일

def get_weekday(x):
    days = ['월','화', '수', '목', '금', '토', '일']
    return days[date.weekday(x)]

data['요일'] = data['datetime'].apply(lambda x: get_weekday(x))

# %%
data.head(3)
# Out:
#        측정일시 측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스농도(ppm)  \
# 0  20200101  강남구         0.037      0.003           0.7         0.003
# 1  20200101  성북구         0.044      0.004           0.9         0.003
# 2  20200101   세곡         0.015      0.005           0.8         0.004
#
#    미세먼지농도(㎍/㎥)  초미세먼지농도(㎍/㎥)  year  month  day   datetime  season 상하반기 요일
# 0         31.0          23.0  2020      1    1 2020-01-01  WINTER  상반기  수
# 1         33.0          21.0  2020      1    1 2020-01-01  WINTER  상반기  수
# 2         27.0          18.0  2020      1    1 2020-01-01  WINTER  상반기  수

# %% [markdown]
# ## ***Feature Making***

# %%
tr = data.copy()

# %%
features = []

# %%
# 측정소별 년도별 대기오염도 평균

for k in data.columns[2:8]:
    lst = ['측정소명']
    t = pd.pivot_table(tr, index='측정소명', columns='year', values=str(k), 
                   aggfunc=np.mean).fillna(0).astype(float).reset_index()
    # 컬럼명 변경
    for i in range(1, 4):
        lst.append(str(t.columns[i]) +'년_'+ str(k))
    t.columns = lst
    
    features.append(t)
    
display(t)
# Out:
#       측정소명  2020년_초미세먼지농도(㎍/㎥)  2021년_초미세먼지농도(㎍/㎥)  2022년_초미세먼지농도(㎍/㎥)
# 0      강남구           20.885246           20.021918           17.167763
# 1     강남대로           18.825137           19.380822           18.523026
# 2      강동구           22.948087           20.767123           17.891447
# 3     강변북로           19.767760           21.024658           18.240132
# 4      강북구           21.371585           18.991781           18.151316
# 5      강서구           20.811475           20.926027           17.809211
# 6     공항대로           19.300546           20.372603           18.888158
# 7      관악구           19.153005           18.465753           17.641447
# 8      관악산           15.622951           15.876712           16.131579
# 9      광진구           19.748634           19.501370           17.674342
# 10     구로구           20.259563           19.542466           16.095395
# 11      궁동           21.330601           19.142466            0.000000
# 12     금천구           22.142077           21.487671           18.062500
# 13      남산           17.800546           18.408219           14.569079
# 14     노원구           21.459016           20.849315           19.595395
# 15     도봉구           19.333333           18.260274           16.542763
# 16    도산대로           19.685792           20.860274           18.680921
# 17    동대문구           19.136612           19.854795           18.565789
# 18     동작구           22.196721           20.873973           19.648026
# 19    동작대로           18.224044           19.424658           18.796053
# 20     마포구           20.781421           19.016438           16.927632
# 21  마포아트센터           18.751366           19.783562           15.868421
# 22     북한산           15.407104           17.608219           15.016447
# 23    서대문구           19.530055           19.613699           15.759868
# 24     서울숲           16.519126           19.273973           15.121711
# 25     서초구           20.923497           19.871233           16.391447
# 26     성동구           21.076503           19.046575           15.963816
# 27     성북구           19.068306           17.715068           17.069079
# 28      세곡           19.658470           19.956164           17.703947
# 29     송파구           20.680328           19.043836           17.796053
# 30    시흥대로           23.136612           22.673973           18.315789
# 31     신촌로           23.437158           21.709589           19.286184
# 32     양천구           21.882514           21.331507           19.842105
# 33    영등포구           20.650273           20.512329           18.319079
# 34    영등포로           22.762295           20.586301           18.802632
# 35   올림픽공원           19.051913           19.139726           18.509868
# 36     용산구           19.983607           18.745205           18.585526
# 37     은평구           19.040984           20.126027           19.457237
# 38  자연사박물관           19.770492           18.452055           15.671053
# 39     정릉로           22.464481           20.032877           19.319079
# 40      종로           22.065574           18.276712           16.950658
# 41     종로구           21.489071           20.446575           18.549342
# 42      중구           23.267760           20.542466           18.476974
# 43     중랑구           19.125683           18.287671           17.453947
# 44    천호대로           21.166667           20.663014           18.075658
# 45    청계천로           26.106557           22.471233           19.335526
# 46    한강대로           20.655738           20.427397           18.845395
# 47      항동            0.000000            0.000000           16.128289
# 48      행주           19.803279           19.764384           16.003289
# 49     홍릉로           20.243169           20.216438           19.605263
# 50     화랑로           19.560109           19.660274           18.519737

# %%
# 측정소별 월별 대기오염도 평균

for k in data.columns[2:8]:
    lst = ['측정소명']
    t = pd.pivot_table(tr, index='측정소명', columns='month', values=str(k), 
                   aggfunc=np.mean).fillna(0).astype(float).reset_index()
    # 컬럼명 변경
    for i in range(1, 13):
        lst.append(str(t.columns[i]) +'월_'+ str(k))
    t.columns = lst
    
    features.append(t)
    
display(t)
# Out:
#       측정소명  1월_초미세먼지농도(㎍/㎥)  2월_초미세먼지농도(㎍/㎥)  3월_초미세먼지농도(㎍/㎥)  \
# 0      강남구        25.268817        26.764706        26.322581
# 1     강남대로        25.741935        27.435294        27.182796
# 2      강동구        30.279570        29.917647        27.483871
# 3     강변북로        27.215054        28.588235        27.956989
# 4      강북구        27.365591        28.411765        26.129032
# 5      강서구        25.989247        27.411765        26.451613
# 6     공항대로        27.430108        27.905882        25.967742
# 7      관악구        23.741935        25.376471        23.741935
# 8      관악산        19.064516        20.105882        21.258065
# 9      광진구        24.440860        27.035294        25.559140
# 10     구로구        24.279570        26.847059        28.645161
# 11      궁동        27.145161        27.192982        30.209677
# 12     금천구        28.860215        29.576471        26.763441
# 13      남산        23.419355        23.305882        23.365591
# 14     노원구        29.741935        30.447059        26.774194
# 15     도봉구        24.526882        26.600000        25.258065
# 16    도산대로        25.322581        27.011765        27.010753
# 17    동대문구        26.215054        25.611765        23.731183
# 18     동작구        28.430108        30.458824        28.075269
# 19    동작대로        25.731183        27.505882        25.139785
# 20     마포구        25.763441        27.882353        25.193548
# 21  마포아트센터        24.236559        25.258824        26.118280
# 22     북한산        19.634409        23.141176        23.150538
# 23    서대문구        24.569892        28.423529        27.096774
# 24     서울숲        25.010753        25.117647        26.634409
# 25     서초구        25.913978        27.505882        29.322581
# 26     성동구        24.333333        25.435294        25.215054
# 27     성북구        24.021505        25.600000        24.000000
# 46        16.021505        11.733333         14.086022         23.850000
# 47         6.645161         8.400000         11.935484          0.000000
# 48        11.634409         9.577778         11.709677         22.333333
# 49        14.559140        11.033333         15.688172         25.966667
# 50        13.440860        10.677778         12.935484         18.883333
#
#     12월_초미세먼지농도(㎍/㎥)
# 0          24.080645
# 1          25.661290
# 2          27.612903
# 3          27.693548
# 4          24.500000
# 5          23.838710
# 6          24.741935
# 7          22.403226
# 8          17.596774
# 9          25.161290
# 10         24.758065
# 11         24.629032
# 12         25.806452
# 13         24.951613
# 14         28.596774
# 15         25.774194
# 16         26.209677
# 17         28.467742
# 18         26.338710
# 19         21.758065
# 20         23.596774
# 21         23.967742
# 22         20.774194
# 23         23.645161
# 24         25.129032
# 25         24.951613
# 26         22.096774
# 27         22.435484
# 28         26.983871
# 29         23.806452
# 30         25.370968
# 31         26.677419
# 32         27.274194
# 33         25.435484
# 34         24.467742
# 35         25.129032
# 36         23.064516
# 37         24.322581
# 38         25.483871
# 39         24.774194
# 40         23.258065
# 41         26.500000
# 42         26.725806
# 43         22.483871
# 44         27.967742
# 45         28.016129
# 46         22.032258
# 47          0.000000
# 48         25.951613
# 49         25.790323
# 50         24.467742

# %%
# 측정소별 요일별 대기오염도 평균

for k in data.columns[2:8]:
    lst = ['측정소명']
    t = pd.pivot_table(tr, index='측정소명', columns='요일', values=str(k), 
                   aggfunc=np.mean).fillna(0).astype(float).reset_index()
    # 컬럼명 변경
    for i in range(1, 8):
        lst.append(str(t.columns[i]) +'_'+ str(k))
    t.columns = lst
    
    features.append(t)
    
display(t)
# Out:
#       측정소명  금_초미세먼지농도(㎍/㎥)  목_초미세먼지농도(㎍/㎥)  수_초미세먼지농도(㎍/㎥)  월_초미세먼지농도(㎍/㎥)  \
# 0      강남구       21.087838       19.851351       18.851351       18.074324
# 1     강남대로       21.006757       18.986486       17.925676       17.837838
# 2      강동구       22.283784       21.094595       19.979730       19.331081
# 3     강변북로       21.472973       20.182432       19.040541       18.391892
# 4      강북구       21.094595       19.952703       18.871622       18.182432
# 5      강서구       22.067568       20.162162       19.027027       18.385135
# 6     공항대로       21.324324       20.020270       18.952703       18.331081
# 7      관악구       20.250000       18.452703       17.547297       16.979730
# 8      관악산       18.074324       16.101351       15.425676       14.837838
# 9      광진구       20.445946       19.270270       18.222973       17.797297
# 10     구로구       21.094595       18.567568       17.236486       17.891892
# 11      궁동       21.790476       21.161905       19.609524       18.750000
# 12     금천구       22.979730       21.000000       19.628378       18.702703
# 13      남산       18.993243       17.594595       16.398649       15.574324
# 14     노원구       22.418919       21.027027       19.554054       19.351351
# 15     도봉구       19.898649       18.310811       16.945946       17.094595
# 16    도산대로       21.918919       20.054054       18.608108       18.533784
# 17    동대문구       20.567568       19.486486       18.621622       17.993243
# 18     동작구       22.925676       21.067568       19.878378       19.594595
# 19    동작대로       20.871622       19.209459       17.736486       17.601351
# 20     마포구       21.060811       19.162162       17.972973       17.763514
# 21  마포아트센터       20.101351       18.777027       17.506757       16.729730
# 34       21.141892       22.574324       19.197279
# 35       19.527027       20.547297       16.938776
# 36       19.885135       20.445946       17.544218
# 37       19.648649       21.182432       17.863946
# 38       18.452703       19.385135       16.047619
# 39       21.168919       22.033784       18.700680
# 40       19.466216       20.209459       17.748299
# 41       20.689189       21.452703       18.619048
# 42       21.155405       22.141892       19.129252
# 43       18.959459       19.378378       16.693878
# 44       20.641892       21.202703       18.340136
# 45       22.635135       23.810811       21.231293
# 46       20.135135       21.209459       18.564626
# 47       16.727273       19.522727       13.534884
# 48       19.202703       19.479730       17.183673
# 49       20.310811       21.324324       18.394558
# 50       19.722973       20.493243       17.469388

# %%
# 측정소별 계절 대기오염도 평균

for k in data.columns[2:8]:
    lst = ['측정소명']
    t = pd.pivot_table(tr, index='측정소명', columns='season', values=str(k), 
                   aggfunc=np.mean).fillna(0).astype(float).reset_index()
    # 컬럼명 변경
    for i in range(1, 5):
        lst.append(t.columns[i] +'_'+ str(k))
    t.columns = lst
    
    features.append(t)

display(t)
# Out:
#       측정소명  FALL_초미세먼지농도(㎍/㎥)  SPRING_초미세먼지농도(㎍/㎥)  SUMMER_초미세먼지농도(㎍/㎥)  \
# 0      강남구          15.082305            21.597826            16.039855
# 1     강남대로          15.905350            22.014493            12.090580
# 2      강동구          16.094650            22.250000            15.561594
# 3     강변북로          16.045267            22.373188            13.413043
# 4      강북구          14.584362            21.391304            15.742754
# 5      강서구          15.893004            21.952899            16.387681
# 6     공항대로          13.893004            21.615942            16.097826
# 7      관악구          14.790123            20.159420            15.221014
# 8      관악산          12.399177            19.159420            12.836957
# 9      광진구          14.691358            21.282609            15.014493
# 10     구로구          14.831276            24.097826            11.271739
# 11      궁동          15.500000            22.407609            16.793478
# 12     금천구          16.987654            21.818841            16.268116
# 13      남산          14.102881            19.514493            11.391304
# 14     노원구          16.559671            22.242754            14.967391
# 15     도봉구          14.102881            20.971014            12.373188
# 16    도산대로          16.119342            23.253623            14.083333
# 17    동대문구          15.888889            19.554348            15.423913
# 18     동작구          16.300412            23.442029            16.010870
# 19    동작대로          13.041152            22.250000            14.797101
# 20     마포구          15.440329            20.445652            14.742754
# 21  마포아트센터          14.374486            20.992754            13.528986
# 22     북한산          13.572016            19.326087            10.572464
# 23    서대문구          14.238683            22.253623            12.061594
# 24     서울숲          11.773663            21.177536            10.699275
# 25     서초구          14.683128            23.923913            12.420290
# 26     성동구          14.407407            20.956522            16.083333
# 27     성북구          13.913580            20.615942            13.630435
# 28      세곡          13.814815            23.257246            12.804348
# 29     송파구          15.777778            20.862319            15.677536
# 30    시흥대로          17.353909            23.456522            18.557971
# 31     신촌로          17.872428            23.605072            17.032609
# 32     양천구          17.320988            22.028986            16.007246
# 33    영등포구          16.230453            21.307971            16.166667
# 34    영등포로          17.246914            22.590580            16.847826
# 35   올림픽공원          13.493827            22.782609            13.786232
# 36     용산구          15.024691            20.735507            15.884058
# 37     은평구          14.724280            23.666667            14.974638
# 38  자연사박물관          13.658436            20.554348            12.670290
# 39     정릉로          15.201646            23.293478            16.963768
# 40      종로          15.144033            21.061594            15.713768
# 41     종로구          15.934156            21.782609            15.561594
# 42      중구          16.135802            22.760870            16.677536
# 43     중랑구          14.296296            20.202899            15.478261
# 44    천호대로          16.078189            21.231884            15.326087
# 45    청계천로          19.028807            24.695652            18.934783
# 46    한강대로          15.625514            22.757246            18.105072
# 47      항동          10.196721            20.326087             9.434783
# 48      행주          13.543210            21.300725            14.510870
# 49     홍릉로          16.502058            21.652174            16.380435
# 50     화랑로          13.567901            21.420290            15.670290
#
#     WINTER_초미세먼지농도(㎍/㎥)
# 0             25.491667
# 1             26.320833
# 2             29.462500
# 3             27.825000
# 4             26.995833
# 5             25.937500
# 6             26.904167
# 7             23.975000
# 8             19.054167
# 9             25.545833
# 10            25.312500
# 11            26.298343
# 12            28.325000
# 13            23.775000
# 14            29.695833
# 15            25.583333
# 16            26.150000
# 17            26.583333
# 18            28.608333
# 19            25.333333
# 20            25.954167
# 21            24.529167
# 22            21.170833
# 23            25.695833
# 24            25.079167
# 25            26.229167
# 26            24.145833
# 27            24.170833
# 28            27.295833
# 29            25.045833
# 30            27.079167
# 31            28.358333
# 32            29.666667
# 33            26.362500
# 34            27.020833
# 35            25.891667
# 36            25.200000
# 37            24.945833
# 38            26.025000
# 39            27.508333
# 40            25.291667
# 41            28.283333
# 42            28.437500
# 43            23.579167
# 44            28.279167
# 45            29.037500
# 46            23.625000
# 47            26.152542
# 48            25.633333
# 49            26.004167
# 50            26.795833

# %%
# 측정소별 상하반기 대기오염도 평균

for k in data.columns[2:8]:
    lst = ['측정소명']
    t = pd.pivot_table(tr, index='측정소명', columns='상하반기', values=str(k), 
                   aggfunc=np.mean).fillna(0).astype(float).reset_index()
    # 컬럼명 변경
    for i in range(1, 3):
        lst.append(t.columns[i] +'_'+ str(k))
    t.columns = lst
    
    features.append(t)

display(t)
# Out:
#       측정소명  상반기_초미세먼지농도(㎍/㎥)  하반기_초미세먼지농도(㎍/㎥)
# 0      강남구         22.468750         16.187373
# 1     강남대로         22.373162         15.120163
# 2      강동구         24.161765         16.851324
# 3     강변북로         23.136029         16.024440
# 4      강북구         22.976103         15.830957
# 5      강서구         22.933824         16.686354
# 6     공항대로         23.058824         15.678208
# 7      관악구         21.091912         15.558045
# 8      관악산         18.792279         12.615071
# 9      광진구         22.049632         15.731161
# 10     구로구         22.825368         14.305499
# 11      궁동         23.699725         16.823370
# 12     금천구         23.599265         17.515275
# 13      남산         19.937500         13.883910
# 14     노원구         23.891544         17.156823
# 15     도봉구         21.580882         14.317719
# 16    도산대로         23.213235         16.028513
# 17    동대문구         21.224265         17.004073
# 18     동작구         24.566176         17.010183
# 19    동작대로         22.884191         14.307536
# 20     마포구         21.863971         15.883910
# 21  마포아트센터         21.586397         14.592668
# 22     북한산         18.909926         12.920570
# 23    서대문구         22.378676         14.101833
# 24     서울숲         21.180147         12.537678
# 25     서초구         23.477941         14.505092
# 26     성동구         21.886029         15.505092
# 27     성북구         21.318015         14.331976
# 28      세곡         23.553309         14.354379
# 29     송파구         21.990809         16.226069
# 30    시흥대로         24.459559         18.342159
# 31     신촌로         24.700368         18.183299
# 32     양천구         23.944853         17.924644
# 33    영등포구         22.516544         17.036660
# 34    영등포로         23.718750         17.633401
# 35   올림픽공원         23.033088         14.370672
# 36     용산구         22.001838         15.961303
# 37     은평구         23.308824         15.376782
# 38  자연사박물관         21.691176         14.124236
# 39     정릉로         24.340074         16.631365
# 40      종로         22.104779         16.038697
# 41     종로구         23.435662         16.737271
# 42      중구         24.167279         17.279022
# 43     중랑구         20.966912         15.427699
# 44    천호대로         22.965074         16.885947
# 45    청계천로         25.626838         19.743381
# 46    한강대로         22.775735         17.016293
# 47      항동         20.381215          9.869919
# 48      행주         21.946691         15.046843
# 49     홍릉로         22.591912         17.226069
# 50     화랑로         22.898897         15.291242

# %%
분석_data = pd.DataFrame(features[0]['측정소명'])

# %%
idx_data = 분석_data.copy()

# %%
for f in features :
    분석_data = pd.merge(분석_data, f, how='left',on='측정소명')
display(분석_data.shape)
# Out:
# (51, 169)

# %%
분석_data
# Out:
#       측정소명  2020년_이산화질소농도(ppm)  2021년_이산화질소농도(ppm)  2022년_이산화질소농도(ppm)  \
# 0      강남구            0.025456            0.023997            0.021138
# 1     강남대로            0.033691            0.031915            0.030441
# 2      강동구            0.024727            0.022315            0.018220
# 3     강변북로            0.033719            0.030652            0.031352
# 4      강북구            0.019697            0.016211            0.013437
# 5      강서구            0.023530            0.025704            0.020043
# 6     공항대로            0.029150            0.033164            0.028043
# 7      관악구            0.027904            0.027403            0.021480
# 8      관악산            0.011036            0.008647            0.008418
# 9      광진구            0.020052            0.020537            0.018043
# 10     구로구            0.022142            0.023249            0.018069
# 11      궁동            0.023131            0.023422            0.000000
# 12     금천구            0.025175            0.025745            0.021118
# 13      남산            0.021514            0.016485            0.017678
# 14     노원구            0.022167            0.022088            0.018086
# 15     도봉구            0.018432            0.016860            0.014530
# 16    도산대로            0.030852            0.030625            0.024247
# 17    동대문구            0.024967            0.025000            0.019322
# 18     동작구            0.024765            0.024181            0.019260
# 19    동작대로            0.040473            0.038573            0.033033
# 20     마포구            0.027538            0.027351            0.021368
# 21  마포아트센터            0.022609            0.022721            0.020112
# 22     북한산            0.011008            0.010707            0.008569
# 23    서대문구            0.019541            0.017668            0.016362
# 24     서울숲            0.022249            0.024077            0.019191
# 25     서초구            0.026577            0.025093            0.020237
# 26     성동구            0.024582            0.027189            0.018368
# 27     성북구            0.027842            0.025373            0.021678
# 28      세곡            0.026164            0.024419            0.020822
# 29     송파구            0.027623            0.026833            0.022237
# 30    시흥대로            0.037945            0.041605            0.033951
# 31     신촌로            0.036492            0.038671            0.032957
# 32     양천구            0.025803            0.025715            0.019349
# 33    영등포구            0.026036            0.026704            0.021342
# 34    영등포로            0.037077            0.035479            0.029862
# 35   올림픽공원            0.018601            0.020608            0.018599
# 36     용산구            0.020566            0.022090            0.019845
# 37     은평구            0.017079            0.017644            0.015668
# 38  자연사박물관            0.018508            0.020156            0.016826
# 39     정릉로            0.032604            0.037923            0.033270
# 강동구             0.410959            0.358224            0.002828  ...
#
#       상반기_오존농도(ppm)  하반기_오존농도(ppm)  상반기_일산화탄소농도(ppm)  하반기_일산화탄소농도(ppm)  \
# 측정소명
# 강남구        0.030849       0.025613          0.479228          0.408147
# 강남대로       0.022381       0.017224          0.683824          0.673116
# 강동구        0.027474       0.021283          0.438603          0.382281
#
#       상반기_아황산가스농도(ppm)  하반기_아황산가스농도(ppm)  상반기_미세먼지농도(㎍/㎥)  하반기_미세먼지농도(㎍/㎥)  \
# 측정소명
# 강남구           0.003208          0.003126        39.459559        26.460285
# 강남대로          0.003050          0.003151        46.139706        28.441955
# 강동구           0.002717          0.002544        43.588235        28.126273
#
#       상반기_초미세먼지농도(㎍/㎥)  하반기_초미세먼지농도(㎍/㎥)
# 측정소명
# 강남구          22.468750         16.187373
# 강남대로         22.373162         15.120163
# 강동구          24.161765         16.851324
#
# [3 rows x 168 columns]

# %%
path = "c:/Windows/Fonts/malgun.ttf"
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system...')
rc('axes', unicode_minus=False) 

# %matplotlib inline

# %%
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage, cut_tree

plt.figure(figsize=(14,6))
clust_single = linkage(분석_data, method='single')

dendrogram(clust_single)
plt.xticks(rotation=60, fontsize=15)
plt.show()

# %% [markdown]
# #### Complete

# %%
clust_complete = linkage(분석_data, method='complete')

plt.figure(figsize=(13,6))
dendrogram(clust_complete)
plt.xticks(rotation=60, fontsize=15)
plt.show()

# %% [markdown]
# #### Average

# %%
clust_avg = linkage(분석_data, method='average')

plt.figure(figsize=(14,6))
dendrogram(clust_avg)
plt.xticks(rotation=60, fontsize=15)
plt.show()

# %% [markdown]
# #### Ward

# %%
clust_ward = linkage(분석_data, method='ward')

plt.figure(figsize=(14,6))
dendrogram(clust_ward)
plt.xticks(rotation=60, fontsize=15)
plt.show()

# %% [markdown]
# ***47, 11번 인덱스 항동 제외하고 진행***

# %%
분석_data.iloc[47].name
# Out:
# '항동'

# %%
분석_data.iloc[11].name
# Out:
# '궁동'

# %% [markdown]
# 47번 인덱스 항동 제거전 Linkage Method
# ![KakaoTalk_20221215_122900349.png](attachment:KakaoTalk_20221215_122900349.png)

# %% [markdown]
# 47번 인덱스 항동을 제거하고 11번 인덱스 궁동 제거전 Linkage Method
# ![image.png](attachment:image.png)

# %%
분석_data = 분석_data.drop(index = '항동')
분석_data = 분석_data.drop(index = '궁동')

# %%
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage, cut_tree

plt.figure(figsize=(14,6))
clust_single = linkage(분석_data, method='single')

dendrogram(clust_single)
plt.xticks(rotation=60, fontsize=15)
plt.show()

# %% [markdown]
# #### Complete

# %%
clust_complete = linkage(분석_data, method='complete')

plt.figure(figsize=(13,6))
dendrogram(clust_complete)
plt.xticks(rotation=60, fontsize=15)
plt.show()

# %% [markdown]
# #### Average

# %%
clust_avg = linkage(분석_data, method='average')

plt.figure(figsize=(14,6))
dendrogram(clust_avg)
plt.xticks(rotation=60, fontsize=15)
plt.show()

# %% [markdown]
# #### Ward

# %%
clust_ward = linkage(분석_data, method='ward')

plt.figure(figsize=(14,6))
dendrogram(clust_ward)
plt.xticks(rotation=60, fontsize=15)
plt.show()

# %%
# 적절한 군집화 개수 파악
from sklearn.cluster import KMeans

wss=[]
for k in np.arange(2,15):
    km_k = KMeans(n_clusters=k).fit(분석_data)
    wss.append(km_k.inertia_)
    
plt.plot(np.arange(2,15),wss, 'bx-')
plt.xlabel('K')
plt.ylabel('WSS')
plt.axvline(5,c='r',alpha=0.4)
plt.axvline(6,c='r',alpha=0.4)
plt.show()

# %% [markdown]
# 4~6개의 군집이 가장 좋다고 판단

# %%
# 군집분석의 해 파악
print('single :\n', pd.Series(cut_tree(clust_single, 6).squeeze()).value_counts())
print('complete :\n', pd.Series(cut_tree(clust_complete, 6).squeeze()).value_counts())
print('average :\n', pd.Series(cut_tree(clust_avg, 6).squeeze()).value_counts())
print('ward :\n', pd.Series(cut_tree(clust_ward, 6).squeeze()).value_counts())
# Out:
# single :
#  0    43
# 4     2
# 1     1
# 2     1
# 3     1
# 5     1
# dtype: int64
# complete :
#  0    16
# 2    11
# 1    10
# 3     7
# 4     3
# 5     2
# dtype: int64
# average :
#  0    19
# 1    17
# 2     4
# 3     4
# 4     3
# 5     2
# dtype: int64
# ward :
#  2    16
# 1    14
# 0     9
# 3     4
# 4     3
# 5     3
# dtype: int64

# %% [markdown]
# 가장 잘 나누어졌다고 판단되는 ward방법의 6개 군집화로 진행!!

# %%
# 잘 나누어진것같은 ward방법 사용
cluster = cut_tree(clust_ward, 6)
분석_data['cluster'] = cluster
분석_data.cluster = 분석_data.cluster.astype('category')
분석_data.head()
# Out:
#       2020년_이산화질소농도(ppm)  2021년_이산화질소농도(ppm)  2022년_이산화질소농도(ppm)  \
# 측정소명
# 강남구             0.025456            0.023997            0.021138
# 강남대로            0.033691            0.031915            0.030441
# 강동구             0.024727            0.022315            0.018220
# 강변북로            0.033719            0.030652            0.031352
# 강북구             0.019697            0.016211            0.013437
#
#       2020년_오존농도(ppm)  2021년_오존농도(ppm)  2022년_오존농도(ppm)  2020년_일산화탄소농도(ppm)  \
# 측정소명
# 강남구          0.025423         0.027077         0.033454            0.491803
# 강남대로         0.017732         0.019964         0.022549            0.703279
# 강동구          0.022232         0.024619         0.027214            0.457377
# 강변북로         0.019929         0.021427         0.021967            0.624863
# 강북구          0.024068         0.028619         0.034289            0.448907
#
#       2021년_일산화탄소농도(ppm)  2022년_일산화탄소농도(ppm)  2020년_아황산가스농도(ppm)  ...  \
# 측정소명                                                              ...
# 강남구             0.449315            0.385197            0.002915  ...
# 강남대로            0.703562            0.619408            0.003273  ...
# 강동구             0.410959            0.358224            0.002828  ...
# 강변북로            0.552877            0.543421            0.003484  ...
# 강북구             0.399178            0.388158            0.002626  ...
#
#       하반기_오존농도(ppm)  상반기_일산화탄소농도(ppm)  하반기_일산화탄소농도(ppm)  상반기_아황산가스농도(ppm)  \
# 측정소명
# 강남구        0.025613          0.479228          0.408147          0.003208
# 강남대로       0.017224          0.683824          0.673116          0.003050
# 강동구        0.021283          0.438603          0.382281          0.002717
# 강변북로       0.018827          0.606801          0.540937          0.003305
# 강북구        0.026151          0.439154          0.385132          0.002550
#
#       하반기_아황산가스농도(ppm)  상반기_미세먼지농도(㎍/㎥)  하반기_미세먼지농도(㎍/㎥)  상반기_초미세먼지농도(㎍/㎥)  \
# 측정소명
# 강남구           0.003126        39.459559        26.460285         22.468750
# 강남대로          0.003151        46.139706        28.441955         22.373162
# 강동구           0.002544        43.588235        28.126273         24.161765
# 강변북로          0.003159        46.110294        28.024440         23.136029
# 강북구           0.002507        43.884191        29.741344         22.976103
#
#       하반기_초미세먼지농도(㎍/㎥)  cluster
# 측정소명
# 강남구          16.187373        0
# 강남대로         15.120163        1
# 강동구          16.851324        2
# 강변북로         16.024440        1
# 강북구          15.830957        1
#
# [5 rows x 169 columns]

# %%
분석_data.columns
# Out:
# Index(['2020년_이산화질소농도(ppm)', '2021년_이산화질소농도(ppm)', '2022년_이산화질소농도(ppm)',
#        '2020년_오존농도(ppm)', '2021년_오존농도(ppm)', '2022년_오존농도(ppm)',
#        '2020년_일산화탄소농도(ppm)', '2021년_일산화탄소농도(ppm)', '2022년_일산화탄소농도(ppm)',
#        '2020년_아황산가스농도(ppm)',
#        ...
#        '하반기_오존농도(ppm)', '상반기_일산화탄소농도(ppm)', '하반기_일산화탄소농도(ppm)',
#        '상반기_아황산가스농도(ppm)', '하반기_아황산가스농도(ppm)', '상반기_미세먼지농도(㎍/㎥)',
#        '하반기_미세먼지농도(㎍/㎥)', '상반기_초미세먼지농도(㎍/㎥)', '하반기_초미세먼지농도(㎍/㎥)', 'cluster'],
#       dtype='object', length=169)

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x="WINTER_미세먼지농도(㎍/㎥)", y="SUMMER_미세먼지농도(㎍/㎥)", hue="cluster", style="cluster", data=분석_data)
'''
for i in range(분석_data.shape[0]):
    plt.text(x=분석_data['이산화질소농도(ppm)'][i]+0.0008, 
            y=분석_data['오존농도(ppm)'][i]+0.00001,
            s=분석_data.index[i],
            color=sns.color_palette()[분석_data.cluster[i]])
'''            
plt.show()

# %%
분석_data
# Out:
#         2020년_이산화질소농도(ppm)  2021년_이산화질소농도(ppm)  2022년_이산화질소농도(ppm)  \
# 측정소명
# 강남구               0.025456            0.023997            0.021138
# 강남대로              0.033691            0.031915            0.030441
# 강동구               0.024727            0.022315            0.018220
# 강변북로              0.033719            0.030652            0.031352
# 강북구               0.019697            0.016211            0.013437
# 강서구               0.023530            0.025704            0.020043
# 공항대로              0.029150            0.033164            0.028043
# 관악구               0.027904            0.027403            0.021480
# 관악산               0.011036            0.008647            0.008418
# 광진구               0.020052            0.020537            0.018043
# 구로구               0.022142            0.023249            0.018069
# 금천구               0.025175            0.025745            0.021118
# 남산                0.021514            0.016485            0.017678
# 노원구               0.022167            0.022088            0.018086
# 도봉구               0.018432            0.016860            0.014530
# 도산대로              0.030852            0.030625            0.024247
# 동대문구              0.024967            0.025000            0.019322
# 동작구               0.024765            0.024181            0.019260
# 동작대로              0.040473            0.038573            0.033033
# 마포구               0.027538            0.027351            0.021368
# 마포아트센터            0.022609            0.022721            0.020112
# 북한산               0.011008            0.010707            0.008569
# 서대문구              0.019541            0.017668            0.016362
# 서울숲               0.022249            0.024077            0.019191
# 서초구               0.026577            0.025093            0.020237
# 성동구               0.024582            0.027189            0.018368
# 성북구               0.027842            0.025373            0.021678
# 세곡                0.026164            0.024419            0.020822
# 송파구               0.027623            0.026833            0.022237
# 시흥대로              0.037945            0.041605            0.033951
# 신촌로               0.036492            0.038671            0.032957
# 양천구               0.025803            0.025715            0.019349
# 영등포구              0.026036            0.026704            0.021342
# 영등포로              0.037077            0.035479            0.029862
# 올림픽공원             0.018601            0.020608            0.018599
# 용산구               0.020566            0.022090            0.019845
# 은평구               0.017079            0.017644            0.015668
# 자연사박물관            0.018508            0.020156            0.016826
# 정릉로               0.032604            0.037923            0.033270
# 종로                0.024694            0.032121            0.023263
# 종로구               0.024645            0.023290            0.019688
# 종로             16.038697        1
# 종로구            16.737271        2
# 중구             17.279022        2
# 중랑구            15.427699        2
# 천호대로           16.885947        5
# 청계천로           19.743381        1
# 한강대로           17.016293        5
# 행주             15.046843        2
# 홍릉로            17.226069        2
# 화랑로            15.291242        3
#
# [49 rows x 169 columns]

# %% [markdown]
# ## ***3.2. PCA***

# %%
분석_data_pca = 분석_data.reset_index().drop(columns='cluster').copy()

# %%
분석_data_pca.head()
# Out:
#    측정소명  2020년_이산화질소농도(ppm)  2021년_이산화질소농도(ppm)  2022년_이산화질소농도(ppm)  \
# 0   강남구            0.025456            0.023997            0.021138
# 1  강남대로            0.033691            0.031915            0.030441
# 2   강동구            0.024727            0.022315            0.018220
# 3  강변북로            0.033719            0.030652            0.031352
# 4   강북구            0.019697            0.016211            0.013437
#
#    2020년_오존농도(ppm)  2021년_오존농도(ppm)  2022년_오존농도(ppm)  2020년_일산화탄소농도(ppm)  \
# 0         0.025423         0.027077         0.033454            0.491803
# 1         0.017732         0.019964         0.022549            0.703279
# 2         0.022232         0.024619         0.027214            0.457377
# 3         0.019929         0.021427         0.021967            0.624863
# 4         0.024068         0.028619         0.034289            0.448907
#
#    2021년_일산화탄소농도(ppm)  2022년_일산화탄소농도(ppm)  ...  상반기_오존농도(ppm)  하반기_오존농도(ppm)  \
# 0            0.449315            0.385197  ...       0.030849       0.025613
# 1            0.703562            0.619408  ...       0.022381       0.017224
# 2            0.410959            0.358224  ...       0.027474       0.021283
# 3            0.552877            0.543421  ...       0.023068       0.018827
# 4            0.399178            0.388158  ...       0.030954       0.026151
#
#    상반기_일산화탄소농도(ppm)  하반기_일산화탄소농도(ppm)  상반기_아황산가스농도(ppm)  하반기_아황산가스농도(ppm)  \
# 0          0.479228          0.408147          0.003208          0.003126
# 1          0.683824          0.673116          0.003050          0.003151
# 2          0.438603          0.382281          0.002717          0.002544
# 3          0.606801          0.540937          0.003305          0.003159
# 4          0.439154          0.385132          0.002550          0.002507
#
#    상반기_미세먼지농도(㎍/㎥)  하반기_미세먼지농도(㎍/㎥)  상반기_초미세먼지농도(㎍/㎥)  하반기_초미세먼지농도(㎍/㎥)
# 0        39.459559        26.460285         22.468750         16.187373
# 1        46.139706        28.441955         22.373162         15.120163
# 2        43.588235        28.126273         24.161765         16.851324
# 3        46.110294        28.024440         23.136029         16.024440
# 4        43.884191        29.741344         22.976103         15.830957
#
# [5 rows x 169 columns]

# %%
분석_data_pca = 분석_data_pca.groupby('측정소명')[분석_data_pca.columns[2:]].mean().reset_index()

# %%
분석_data_pca = 분석_data_pca.set_index('측정소명')

# %%
from sklearn.decomposition import PCA # 주성분 분석
from sklearn.preprocessing import StandardScaler # 표준화
from pca import pca
model = pca(n_components=6, normalize=True) # 표준화 진행
result = model.fit_transform(분석_data_pca)
# Out:
# [pca] >Processing dataframe..
# [pca] >Normalizing input data per feature (zero mean and unit variance)..
# [pca] >The PCA reduction is performed on the [167] columns of the input dataframe.
# [pca] >Fit using PCA.
# [pca] >Compute loadings and PCs.
# [pca] >Compute explained variance.
# [pca] >Outlier detection using Hotelling T2 test with alpha=[0.05] and n_components=[6]
# [pca] >Outlier detection using SPE/DmodX with n_std=[2]

# %%
result['variance_ratio']
# Out:
# array([0.51711547, 0.12734806, 0.10248531, 0.05625387, 0.04106867,
#        0.03564318])

# %%
# 누적분산
result['variance_ratio'].cumsum()
# Out:
# array([0.51711547, 0.64446353, 0.74694884, 0.80320271, 0.84427138,
#        0.87991456])

# %%
model.plot()
plt.show()

# %%
result['loadings']
# Out:
#      2021년_이산화질소농도(ppm)  2022년_이산화질소농도(ppm)
# 홍릉로     -6.736731   1.090443  -0.612007  0.807883 -3.162703 -1.887280
# 화랑로     -6.492329  -4.549206   0.969403  6.071086 -3.381110  0.656735

# %%
# Make plots

# Scree plot
fig, ax = model.plot(figsize=(10, 6))

# Scatter plot
fig, ax = model.scatter(figsize=(10, 6))

# Biplot
fig, ax = model.biplot(figsize=(10, 6))
# Out:
# [colourmap]> Warning: Colormap [Set1] can not create [49] unique colors! Available unique colors: [9].
# [colourmap]> Warning: Colormap [Set1] can not create [49] unique colors! Available unique colors: [9].
# [pca] >Plot PC1 vs PC2 with loadings.
# [colourmap]> Warning: Colormap [Set1] can not create [49] unique colors! Available unique colors: [9].
# [colourmap]> Warning: Colormap [Set1] can not create [49] unique colors! Available unique colors: [9].

# %%
model.biplot(legend=False)
plt.show()
# Out:
# [pca] >Plot PC1 vs PC2 with loadings.
# [colourmap]> Warning: Colormap [Set1] can not create [49] unique colors! Available unique colors: [9].
# [colourmap]> Warning: Colormap [Set1] can not create [49] unique colors! Available unique colors: [9].

# %% [markdown]
# pca결과 첫번째, 두번째 요인으로 scatter plot을 그려본 결과를 아래에서 군집분석을 진행한 결과와 비교해보면 "남산, 관악산, 북한산", "서대문구, 마포아트센터, 강남구"와 같이 같은 군집으로 묶인 지역들이 비슷한 위치에 찍힌것을 확인할 수 있다.
#
# 또한 원변수를 확인해보면 아황가스농도와 관련된 변수들이 12시방향으로 비슷하게 뻗어있고, 일산화탄소, 오존농도 등의 변수들도 비슷한 방향으로 향하는 것을 알 수 있다. 따라서 같은 feature에서 파생된 원변수들이 비슷한 의미를 가지는 것을 알 수 있다.
#
# 또한 이 feature들이 모두 대기오염과 관련된 feature이기 때문에 전체적으로 왼쪽 위를 향하는 경향을 보이는 것을 확인할 수 있다.

# %% [markdown]
# ## ***3.3. 요인분석***

# %%
#!pip install factor_analyzer

# %%
from factor_analyzer import FactorAnalyzer

# %%
daegi_data2.head()
# Out:
#        측정일시  측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스농도(ppm)  \
# 0  20200101   강남구         0.037      0.003           0.7         0.003
# 1  20200101   성북구         0.044      0.004           0.9         0.003
# 2  20200101    세곡         0.015      0.005           0.8         0.004
# 3  20200101   송파구         0.037      0.003           0.7         0.003
# 4  20200101  시흥대로         0.044      0.003           0.7         0.004
#
#    미세먼지농도(㎍/㎥)  초미세먼지농도(㎍/㎥)
# 0         31.0          23.0
# 1         33.0          21.0
# 2         27.0          18.0
# 3         32.0          22.0
# 4         33.0          24.0

# %%
# 탐색적요인분석
fa = FactorAnalyzer(n_factors=3, rotation='varimax').fit(daegi_data2.iloc[:,2:])
# 결과 출력
print('요인적재량 :\n',pd.DataFrame(fa.loadings_, index=daegi_data2.iloc[:,2:].columns))
# Out:
# 요인적재량 :
#                       0         1         2
# 이산화질소농도(ppm)  0.293223  0.715414 -0.347297
# 오존농도(ppm)     0.042262 -0.277577  0.957202
# 일산화탄소농도(ppm)  0.326494  0.726757 -0.239410
# 아황산가스농도(ppm)  0.196419  0.505673 -0.077910
# 미세먼지농도(㎍/㎥)   0.728332  0.233180  0.014407
# 초미세먼지농도(㎍/㎥)  0.914719  0.397968 -0.021383

# %% [markdown]
# - Factor1
#     - 미세먼지농도, 초미세먼지농도에 대한 factor loading 값이 큼
#     - "미세먼지오염"이라고 명명
# - Factor2
#     - 이산화질소농도, 일산화탄소농도, 아황산가스농도에 대한 factor loading 값이 큼
#     - 자동차의 배기가스에서는 질산화물질(NOx), 일산화탄소(CO), 탄화수소(HC), 총먼지(TSP : Total Solid Particlate), 아황산가스(SO2) 등 대기를 오염시키는 주요 물질 배출
#     - 따라서 "자동차환경오염"이라고 명명
# - Factor3
#     - 오존농도에 대한 factor loading 값이 큼
#     - "오존오염"이라고 명명

# %% [markdown]
# 지역들을 군집분석으로 나눈 군집들을 각각의 요인에 대해 분석하여 해당 지역에 어떠한 조치를 취하면 좋을지 파악해보자!!

# %% [markdown]
# # 4. ***Final Analysis and Troubleshooting***

# %% [markdown]
# daegi_data2 데이터에서 그림에 따라 점수를 6개요인으로 만들고 -> 3개 요인으로 만들기(평균)
# 이렇게 한 결과를 군집화 된 결과에 점수를 비교 -> 점수가 낮은 군집에 대한 조치를 취한다(지역 특징 파악)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
daegi_data2.columns[2:]
# Out:
# Index(['이산화질소농도(ppm)', '오존농도(ppm)', '일산화탄소농도(ppm)', '아황산가스농도(ppm)',
#        '미세먼지농도(㎍/㎥)', '초미세먼지농도(㎍/㎥)'],
#       dtype='object')

# %%
# 위의 표를 바탕으로 점수 설정 (좋음 : 6, 보통 : 4, 나쁨 : 2, 매우나쁨 : 0)
daegi_data2['이산화질소점수'] = daegi_data2['이산화질소농도(ppm)'].apply(lambda x : 6 if x<=0.03 else 4 
                                                                                            if x<=0.06 else 2 
                                                                                            if x<=0.2 else 0)

daegi_data2['오존점수'] = daegi_data2['오존농도(ppm)'].apply(lambda x : 6 if x<=0.03 else 4 
                                                                                            if x<=0.09 else 2 
                                                                                            if x<=0.15 else 0)

daegi_data2['일산화탄소점수'] = daegi_data2['일산화탄소농도(ppm)'].apply(lambda x : 6 if x<=2 else 4 
                                                                                            if x<=9 else 2 
                                                                                            if x<=15 else 0)

daegi_data2['아황산가스점수'] = daegi_data2['아황산가스농도(ppm)'].apply(lambda x : 6 if x<=0.02 else 4 
                                                                                            if x<=0.05 else 2
                                                                                            if x<=0.15 else 0)

daegi_data2['미세먼지점수'] = daegi_data2['미세먼지농도(㎍/㎥)'].apply(lambda x : 6 if x<=30 else 4 
                                                                                            if x<=80 else 2 
                                                                                            if x<=150 else 0)

daegi_data2['초미세먼지점수'] = daegi_data2['초미세먼지농도(㎍/㎥)'].apply(lambda x : 6 if x<=15 else 4 
                                                                                            if x<=50 else 2
                                                                                            if x<=100 else 0)

# %%
daegi_data2
# Out:
#            측정일시  측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스농도(ppm)  \
# 0      20200101   강남구         0.037      0.003           0.7         0.003
# 1      20200101   성북구         0.044      0.004           0.9         0.003
# 2      20200101    세곡         0.015      0.005           0.8         0.004
# 3      20200101   송파구         0.037      0.003           0.7         0.003
# 4      20200101  시흥대로         0.044      0.003           0.7         0.004
# ...         ...   ...           ...        ...           ...           ...
# 51745  20221031   송파구         0.030      0.019           0.4         0.003
# 51746  20221031    세곡         0.029      0.008           1.0         0.003
# 51747  20221031   성북구         0.029      0.022           0.5         0.002
# 51748  20221031   정릉로         0.034      0.015           0.5         0.003
# 51749  20221031   용산구         0.026      0.022           0.4         0.003
#
#        미세먼지농도(㎍/㎥)  초미세먼지농도(㎍/㎥)  이산화질소점수  오존점수  일산화탄소점수  아황산가스점수  미세먼지점수  \
# 0             31.0          23.0        4     6        6        6       4
# 1             33.0          21.0        4     6        6        6       4
# 2             27.0          18.0        6     6        6        6       6
# 3             32.0          22.0        4     6        6        6       4
# 4             33.0          24.0        4     6        6        6       4
# ...            ...           ...      ...   ...      ...      ...     ...
# 51745         26.0          14.0        6     6        6        6       6
# 51746         26.0          12.0        6     6        6        6       6
# 51747         24.0          14.0        6     6        6        6       6
# 51748         27.0          14.0        4     6        6        6       6
# 51749         25.0          14.0        6     6        6        6       6
#
#        초미세먼지점수
# 0            4
# 1            4
# 2            4
# 3            4
# 4            4
# ...        ...
# 51745        6
# 51746        6
# 51747        6
# 51748        6
# 51749        6
#
# [51750 rows x 14 columns]

# %%
daegi_data2.groupby('측정소명')['이산화질소점수'].mean().sort_values(ascending=False)
# Out:
# 측정소명
# 관악산       5.992271
# 북한산       5.988406
# 은평구       5.793237
# 도봉구       5.775845
# 남산        5.773913
# 강북구       5.750725
# 자연사박물관    5.744928
# 서대문구      5.719807
# 항동        5.690789
# 광진구       5.683092
# 올림픽공원     5.683092
# 용산구       5.642512
# 행주        5.615459
# 마포아트센터    5.590338
# 노원구       5.586473
# 구로구       5.580676
# 중랑구       5.578744
# 종로구       5.555556
# 강동구       5.547826
# 강서구       5.536232
# 강남구       5.534300
# 동작구       5.528502
# 궁동        5.526676
# 동대문구      5.524638
# 서울숲       5.524638
# 금천구       5.484058
# 성동구       5.480193
# 중구        5.478261
# 세곡        5.478261
# 영등포구      5.476329
# 양천구       5.470531
# 서초구       5.468599
# 성북구       5.414493
# 마포구       5.389372
# 관악구       5.389372
# 송파구       5.373913
# 종로        5.344928
# 청계천로      5.246377
# 도산대로      5.186473
# 한강대로      5.176812
# 공항대로      5.113043
# 홍릉로       5.103382
# 천호대로      4.964251
# 강남대로      4.962319
# 화랑로       4.944928
# 강변북로      4.894686
# 영등포로      4.778744
# 정릉로       4.771014
# 신촌로       4.604831
# 시흥대로      4.506280
# 동작대로      4.506280
# Name: 이산화질소점수, dtype: float64

# %%
daegi_data2.groupby('측정소명')['오존점수'].mean().sort_values(ascending=False)
# Out:
# 측정소명
# 한강대로      5.793237
# 강남대로      5.721739
# 신촌로       5.671498
# 화랑로       5.659903
# 강변북로      5.617391
# 영등포로      5.609662
# 정릉로       5.605797
# 시흥대로      5.571014
# 동작대로      5.543961
# 천호대로      5.528502
# 공항대로      5.499517
# 종로        5.468599
# 홍릉로       5.466667
# 도산대로      5.449275
# 세곡        5.424155
# 궁동        5.417237
# 용산구       5.375845
# 강동구       5.371981
# 청계천로      5.350725
# 서울숲       5.348792
# 금천구       5.300483
# 영등포구      5.294686
# 행주        5.275362
# 중구        5.259903
# 양천구       5.259903
# 동작구       5.257971
# 성북구       5.256039
# 관악구       5.252174
# 마포구       5.244444
# 광진구       5.236715
# 송파구       5.234783
# 강북구       5.205797
# 강남구       5.174879
# 중랑구       5.172947
# 성동구       5.157488
# 강서구       5.157488
# 노원구       5.155556
# 종로구       5.145894
# 올림픽공원     5.136232
# 서대문구      5.136232
# 서초구       5.128502
# 도봉구       5.095652
# 동대문구      5.091787
# 항동        5.052632
# 구로구       5.051208
# 은평구       5.041546
# 북한산       4.902415
# 마포아트센터    4.885024
# 남산        4.838647
# 자연사박물관    4.784541
# 관악산       4.444444
# Name: 오존점수, dtype: float64

# %%
daegi_data2.groupby('측정소명')['미세먼지점수'].mean().sort_values(ascending=False)
# Out:
# 측정소명
# 북한산       5.263768
# 관악산       5.178744
# 항동        5.151316
# 올림픽공원     5.145894
# 남산        5.126570
# 서대문구      5.099517
# 도봉구       5.082126
# 마포아트센터    5.072464
# 마포구       5.064734
# 자연사박물관    5.058937
# 강남구       5.039614
# 은평구       5.010628
# 광진구       5.006763
# 동대문구      5.006763
# 영등포구      5.006763
# 관악구       5.004831
# 성동구       4.975845
# 서울숲       4.971981
# 금천구       4.966184
# 노원구       4.960386
# 행주        4.958454
# 중랑구       4.954589
# 중구        4.948792
# 성북구       4.944928
# 종로구       4.941063
# 송파구       4.923671
# 화랑로       4.923671
# 용산구       4.914010
# 서초구       4.904348
# 강동구       4.894686
# 정릉로       4.883092
# 구로구       4.879227
# 홍릉로       4.869565
# 강변북로      4.857971
# 영등포로      4.854106
# 세곡        4.852174
# 종로        4.852174
# 양천구       4.840580
# 강북구       4.838647
# 강서구       4.827053
# 강남대로      4.823188
# 동작구       4.819324
# 동작대로      4.803865
# 궁동        4.779754
# 청계천로      4.771014
# 도산대로      4.763285
# 공항대로      4.742029
# 신촌로       4.685990
# 천호대로      4.620290
# 시흥대로      4.620290
# 한강대로      4.488889
# Name: 미세먼지점수, dtype: float64

# %%
daegi_data2.groupby('측정소명')['초미세먼지점수'].mean().sort_values(ascending=False)
# Out:
# 측정소명
# 항동        5.151316
# 북한산       5.132367
# 관악산       5.128502
# 남산        5.072464
# 서울숲       5.062802
# 서대문구      4.995169
# 도봉구       4.983575
# 구로구       4.981643
# 마포아트센터    4.968116
# 자연사박물관    4.968116
# 성북구       4.960386
# 행주        4.952657
# 서초구       4.948792
# 관악구       4.948792
# 강남대로      4.946860
# 중랑구       4.935266
# 마포구       4.919807
# 동작대로      4.906280
# 세곡        4.902415
# 올림픽공원     4.900483
# 화랑로       4.900483
# 성동구       4.892754
# 광진구       4.883092
# 도산대로      4.881159
# 종로        4.871498
# 은평구       4.867633
# 공항대로      4.865700
# 강변북로      4.854106
# 강남구       4.852174
# 영등포구      4.848309
# 용산구       4.846377
# 송파구       4.838647
# 강서구       4.827053
# 동대문구      4.823188
# 강북구       4.819324
# 한강대로      4.811594
# 천호대로      4.790338
# 종로구       4.784541
# 홍릉로       4.780676
# 궁동        4.777018
# 영등포로      4.771014
# 금천구       4.753623
# 중구        4.747826
# 강동구       4.738164
# 노원구       4.738164
# 동작구       4.734300
# 양천구       4.726570
# 신촌로       4.687923
# 시흥대로      4.664734
# 정릉로       4.645411
# 청계천로      4.566184
# Name: 초미세먼지점수, dtype: float64

# %%
print(daegi_data2['이산화질소점수'].value_counts())
print(daegi_data2['오존점수'].value_counts())
print(daegi_data2['일산화탄소점수'].value_counts()) # 일산화탐소 점수는 모두 좋음
print(daegi_data2['아황산가스점수'].value_counts()) # 아황산가스 점수는 모두 좋음
print(daegi_data2['미세먼지점수'].value_counts())
print(daegi_data2['초미세먼지점수'].value_counts())
# Out:
# 6    36580
# 4    14729
# 2      441
# Name: 이산화질소점수, dtype: int64
# 6    33122
# 4    18610
# 2       17
# 0        1
# Name: 오존점수, dtype: int64
# 6    51750
# Name: 일산화탄소점수, dtype: int64
# 6    51750
# Name: 아황산가스점수, dtype: int64
# 6    25734
# 4    24243
# 2     1582
# 0      191
# Name: 미세먼지점수, dtype: int64
# 4    26129
# 6    24045
# 2     1522
# 0       54
# Name: 초미세먼지점수, dtype: int64

# %% [markdown]
# 6개의 피처를 3개의 군집 요인으로 묶어 점수 평균을 구한다.

# %%
# 오존오염은 오존점수 그대로 활용
daegi_data2['자동차환경오염'] = round((daegi_data2['이산화질소점수']+daegi_data2['일산화탄소점수']+daegi_data2['아황산가스점수'])/3,3)
daegi_data2['미세먼지오염'] = (daegi_data2['미세먼지점수']+daegi_data2['초미세먼지점수'])/2

# %%
daegi_data2
# Out:
#            측정일시  측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스농도(ppm)  \
# 0      20200101   강남구         0.037      0.003           0.7         0.003
# 1      20200101   성북구         0.044      0.004           0.9         0.003
# 2      20200101    세곡         0.015      0.005           0.8         0.004
# 3      20200101   송파구         0.037      0.003           0.7         0.003
# 4      20200101  시흥대로         0.044      0.003           0.7         0.004
# ...         ...   ...           ...        ...           ...           ...
# 51745  20221031   송파구         0.030      0.019           0.4         0.003
# 51746  20221031    세곡         0.029      0.008           1.0         0.003
# 51747  20221031   성북구         0.029      0.022           0.5         0.002
# 51748  20221031   정릉로         0.034      0.015           0.5         0.003
# 51749  20221031   용산구         0.026      0.022           0.4         0.003
#
#        미세먼지농도(㎍/㎥)  초미세먼지농도(㎍/㎥)  이산화질소점수  오존점수  일산화탄소점수  아황산가스점수  미세먼지점수  \
# 0             31.0          23.0        4     6        6        6       4
# 1             33.0          21.0        4     6        6        6       4
# 2             27.0          18.0        6     6        6        6       6
# 3             32.0          22.0        4     6        6        6       4
# 4             33.0          24.0        4     6        6        6       4
# ...            ...           ...      ...   ...      ...      ...     ...
# 51745         26.0          14.0        6     6        6        6       6
# 51746         26.0          12.0        6     6        6        6       6
# 51747         24.0          14.0        6     6        6        6       6
# 51748         27.0          14.0        4     6        6        6       6
# 51749         25.0          14.0        6     6        6        6       6
#
#        초미세먼지점수  자동차환경오염  미세먼지오염
# 0            4    5.333     4.0
# 1            4    5.333     4.0
# 2            4    6.000     5.0
# 3            4    5.333     4.0
# 4            4    5.333     4.0
# ...        ...      ...     ...
# 51745        6    6.000     6.0
# 51746        6    6.000     6.0
# 51747        6    6.000     6.0
# 51748        6    5.333     6.0
# 51749        6    6.000     6.0
#
# [51750 rows x 16 columns]

# %%
# 분석과 같이 항동과 궁동 지역의 데이터를 제거하고 판단
daegi_data2 = daegi_data2[daegi_data2.측정소명!="항동"]
daegi_data2 = daegi_data2[daegi_data2.측정소명!="궁동"]

# %%
# 지역별 3개년 환경오염점수 평균
ozone_score = daegi_data2.groupby('측정소명')['오존점수'].mean()
car_score = daegi_data2.groupby('측정소명')['자동차환경오염'].mean()
mise_score = daegi_data2.groupby('측정소명')['미세먼지오염'].mean()

# %%
ozone_score.mean(), car_score.mean(), mise_score.mean()
# Out:
# (5.278714384304447, 5.797587380459429, 4.892556442867001)

# %%
import scipy.stats

scipy.stats.ttest_ind(ozone_score, car_score, equal_var=False)
# Out:
# Ttest_indResult(statistic=-12.637197761007677, pvalue=1.9440663001579254e-19)

# %%
분석_data_pca.shape
# Out:
# (49, 167)

# %% [markdown]
# 분석 결과에 환경오염점수 추가

# %%
분석_data['지역별오존오염평균'] = ozone_score
분석_data['지역별자동차환경오염평균'] = car_score
분석_data['지역별미세먼지오염평균'] = mise_score

# %%
분석_data
# Out:
#         2020년_이산화질소농도(ppm)  2021년_이산화질소농도(ppm)  2022년_이산화질소농도(ppm)  \
# 측정소명
# 강남구               0.025456            0.023997            0.021138
# 강남대로              0.033691            0.031915            0.030441
# 강동구               0.024727            0.022315            0.018220
# 강변북로              0.033719            0.030652            0.031352
# 강북구               0.019697            0.016211            0.013437
# 강서구               0.023530            0.025704            0.020043
# 공항대로              0.029150            0.033164            0.028043
# 관악구               0.027904            0.027403            0.021480
# 관악산               0.011036            0.008647            0.008418
# 광진구               0.020052            0.020537            0.018043
# 구로구               0.022142            0.023249            0.018069
# 금천구               0.025175            0.025745            0.021118
# 남산                0.021514            0.016485            0.017678
# 노원구               0.022167            0.022088            0.018086
# 도봉구               0.018432            0.016860            0.014530
# 도산대로              0.030852            0.030625            0.024247
# 동대문구              0.024967            0.025000            0.019322
# 동작구               0.024765            0.024181            0.019260
# 동작대로              0.040473            0.038573            0.033033
# 마포구               0.027538            0.027351            0.021368
# 마포아트센터            0.022609            0.022721            0.020112
# 북한산               0.011008            0.010707            0.008569
# 서대문구              0.019541            0.017668            0.016362
# 서울숲               0.022249            0.024077            0.019191
# 서초구               0.026577            0.025093            0.020237
# 성동구               0.024582            0.027189            0.018368
# 성북구               0.027842            0.025373            0.021678
# 세곡                0.026164            0.024419            0.020822
# 송파구               0.027623            0.026833            0.022237
# 시흥대로              0.037945            0.041605            0.033951
# 신촌로               0.036492            0.038671            0.032957
# 양천구               0.025803            0.025715            0.019349
# 영등포구              0.026036            0.026704            0.021342
# 영등포로              0.037077            0.035479            0.029862
# 올림픽공원             0.018601            0.020608            0.018599
# 용산구               0.020566            0.022090            0.019845
# 은평구               0.017079            0.017644            0.015668
# 자연사박물관            0.018508            0.020156            0.016826
# 정릉로               0.032604            0.037923            0.033270
# 시흥대로       4.642512
# 신촌로        4.686957
# 양천구        4.783575
# 영등포구       4.927536
# 영등포로       4.812560
# 올림픽공원      5.023188
# 용산구        4.880193
# 은평구        4.939130
# 자연사박물관     5.013527
# 정릉로        4.764251
# 종로         4.861836
# 종로구        4.862802
# 중구         4.848309
# 중랑구        4.944928
# 천호대로       4.705314
# 청계천로       4.668599
# 한강대로       4.650242
# 행주         4.955556
# 홍릉로        4.825121
# 화랑로        4.912077
#
# [49 rows x 172 columns]

# %%
# 3에 가까울 수록 좋음
print('오존오염 :\n',분석_data.groupby('cluster')['지역별오존오염평균'].mean())
print('자동차환경오염 :\n',분석_data.groupby('cluster')['지역별자동차환경오염평균'].mean())
print('미세먼지오염 :\n',분석_data.groupby('cluster')['지역별미세먼지오염평균'].mean())
# Out:
# 오존오염 :
#  cluster
# 0    5.081696
# 1    5.383851
# 2    5.260024
# 3    5.577295
# 4    4.728502
# 5    5.630918
# Name: 지역별오존오염평균, dtype: float64
# 자동차환경오염 :
#  cluster
# 0    5.885650
# 1    5.757790
# 2    5.828582
# 3    5.611108
# 4    5.972719
# 5    5.627323
# Name: 지역별자동차환경오염평균, dtype: float64
# 미세먼지오염 :
#  cluster
# 0    4.995491
# 1    4.824569
# 2    4.902959
# 3    4.833816
# 4    5.150403
# 5    4.666023
# Name: 지역별미세먼지오염평균, dtype: float64

# %%
print('cluster 0 : ',분석_data.query('cluster==0').index)
print('cluster 1 : ',분석_data.query('cluster==1').index)
print('cluster 2 : ',분석_data.query('cluster==2').index)
print('cluster 3 : ',분석_data.query('cluster==3').index)
print('cluster 4 : ',분석_data.query('cluster==4').index)
print('cluster 5 : ',분석_data.query('cluster==5').index)
# Out:
# cluster 0 :  Index(['강남구', '광진구', '도봉구', '마포구', '마포아트센터', '서대문구', '올림픽공원', '은평구', '자연사박물관'], dtype='object', name='측정소명')
# cluster 1 :  Index(['강남대로', '강변북로', '강북구', '강서구', '구로구', '도산대로', '동작구', '서초구', '세곡', '신촌로',
#        '양천구', '영등포로', '종로', '청계천로'],
#       dtype='object', name='측정소명')
# cluster 2 :  Index(['강동구', '관악구', '금천구', '노원구', '동대문구', '서울숲', '성동구', '성북구', '송파구', '영등포구',
#        '용산구', '종로구', '중구', '중랑구', '행주', '홍릉로'],
#       dtype='object', name='측정소명')
# cluster 3 :  Index(['공항대로', '동작대로', '정릉로', '화랑로'], dtype='object', name='측정소명')
# cluster 4 :  Index(['관악산', '남산', '북한산'], dtype='object', name='측정소명')
# cluster 5 :  Index(['시흥대로', '천호대로', '한강대로'], dtype='object', name='측정소명')

# %% [markdown]
# **서울시 간선도로 지점별 교통량 통계**
# https://data.seoul.go.kr/dataList/10692/S/2/datasetView.do;jsessionid=57A259531068A4DD2C15F58EF34CE17B.new_portal-svr-21

# %% [markdown]
# 간선도로 종류 : 강남대로, 강변북로, 도산대로, 신촌로, 영등포로, 청계천로 / 홍릉로 / 공항대로, 동작대로, 정릉로, 화랑로 / 시흥대로, 천호대로, 한강대로

# %%
gyotong = pd.read_csv(os.path.abspath("../프로젝트/Data")+'/간선도로+지점별+교통량_20221216054656.csv').rename(columns={'간선도로 지점별(1)':'지점'}).sort_values('지점')

# %% [markdown]
# cluster0

# %%
gyotong.query('지점=="강남대로(신사역)"')
# Out:
#            지점    2017   2018   2019   2020   2021
# 42  강남대로(신사역)  102260  76324  74310  69076  64676

# %%
gyotong.query('지점=="영등포로(오목교)"')
# Out:
#            지점   2017   2018   2019   2020   2021
# 24  영등포로(오목교)  60743  60525  60395  57983  55163

# %% [markdown]
# cluster3

# %%
gyotong.query('지점=="공항대로(발산역)"')
# Out:
#            지점 2017   2018   2019   2020   2021
# 20  공항대로(발산역)    -  55298  53057  49224  50328

# %%
gyotong.query('지점=="동작대로(총신대)"')
# Out:
#            지점    2017   2018   2019   2020   2021
# 30  동작대로(총신대)  114621  91084  89433  84243  82634

# %%
gyotong.query('지점=="화랑로(화랑대역)"')
# Out:
#           지점   2017   2018   2019   2020   2021
# 9  화랑로(화랑대역)  82626  68491  69384  67887  67211

# %% [markdown]
# cluster5

# %%
gyotong.query('지점=="천호대로(군자교)"')
# Out:
#           지점   2017   2018   2019   2020   2021
# 4  천호대로(군자교)  89346  88166  87339  83631  81095

# %%
gyotong.query('지점=="시흥대로(구로디지털단지역)"')
# Out:
#                 지점   2017   2018   2019   2020   2021
# 25  시흥대로(구로디지털단지역)  83401  79366  77602  72929  70587

# %%
gyotong
# Out:
#                         지점    2017    2018    2019    2020    2021
# 34           강남대로(강남역-신분당)   75243   58497   59020   55588   53898
# 42               강남대로(신사역)  102260   76324   74310   69076   64676
# 19               강서로(화곡터널)   41244   39923   39662   38216   37711
# 22          경인로(거리공원입구교차로)   54732   54116   53049   51005   46190
# 27                경인로(서울교)   95127   94691   94686   89962   90915
# 21               경인로(오류IC)   53398   50370   51205   47896   46216
# 20               공항대로(발산역)       -   55298   53057   49224   50328
# 26              국회대로(여의2교)   87205   66191   65726   58539   53722
# 17        남부순환도로(화곡로입구교차로)   86190   73750   74080   72757   72080
# 32             남부순환로(낙성대역)  108184  101960   99614   96252   90723
# 38             남부순환로(수서IC)   88638  100965  102715   97696   97512
# 18             남부순환로(신월IC)  115471  112480  112228  109885  107216
# 33            남부순환로(예술의전당)   98425   96030   93399   88525   82399
# 40                     노들로       -   64306   64810   59623   57855
# 10                도봉로(쌍문역)   53892   47962   46769   44897   43027
# 11            동부간선도로(월계1교)  125333  120185  121732  117986  119920
# 8             동소문로(길음교사거리)   61797   59831   60188   57141   55686
# 6                 동일로(군자교)   78989   69925   69677   67793   64612
# 12                동일로(노원역)   44916   44400   42237   38770   37561
# 30               동작대로(총신대)  114621   91084   89433   84243   82634
# 2                동호로(금호터널)   71586   68451   67523   63672   61491
# 5                 뚝섬로(용비교)   73520   69442   68858   66376   65644
# 31               문성로(난곡터널)   19627   18411   17197   16389   15411
# 36               반포대로(서초역)  107018   87362   87227   82973   81650
# 43            백제고분로(종합운동장)   40523   37884   38934   36845   36939
# 35            사평대로(고속터미널역)   97375   92933   91268   86362   83240
# 3                서빙고로(한남역)   95841   92374   90527   86945   86338
# 52       석촌호수로(방이삼거리→석촌호수)   19596       -       -       -     NaN
# 51      석촌호수로(신천역~잠실학원사거리)   35981       -       -       -       -
# 15               성산로(연희IC)   83139   81827   81920   75286   73568
# 45             세곡교차로(밤고개길)   48307       -       -       -       -
# 49   송파대로(석촌호수(롯데월드)~석촌호수)   77828       -       -       -       -
# 44               송파대로(송파역)       -   79863   79854   75776   74952
# 25          시흥대로(구로디지털단지역)   83401   79366   77602   72929   70587
# 23              시흥대로(시흥IC)   88054   85063   83254   79212   78500
# 29               양녕로(상도터널)   70074   73391   73358   69640   67482
# 37               언주로(매봉터널)   65521   64513   62718   59920   58894
# 28              여의대방로(여의교)   92782   90192   91513   85745   82385
# 16               연희로(연희IC)   38509   37407   37308   35047   34854
# 24               영등포로(오목교)   60743   60525   60395   57983   55163
# 48       올림픽로(몽촌토성역~올림픽회관)   57360       -       -       -       -
# 47          올림픽로(송파구청~잠실역)   56067       -       -       -       -
# 50  잠실로(석촌호수(롯데월드)~KT송파지사)   28499       -       -       -       -
# 46             종합운동장(올림픽로)   53116       -       -       -       -
# 13          증산로(디지털미디어시티역)   73585   72467   68277   66189   63470
# 0                진흥로(구기터널)   46352   46704   45876   43895   42541
# 4                천호대로(군자교)   89346   88166   87339   83631   81095
# 41               테헤란로(선릉역)   82727   75537   73987   68434   65162
# 14            통일로(산골고개정류장)   66437   67131   67917   66820   65581
# 1              평창문화로(북악터널)   37215   45746   45747   42455   41546
# 39             헌릉로(세곡동사거리)   66463   64100   64788   62667   63340
# 7                화랑로(상월곡역)   62267   70994   71331   69489   67567
# 9                화랑로(화랑대역)   82626   68491   69384   67887   67211

# %% [markdown]
# ### 군집화 결과 분석
# - cluster 0 : 비교적 최근 교통량이 적고, 강남구, 광진구, 마포구, 서대문구, 은평구 등으로 군집화되었다.
# - cluster 1 : 강북구, 강서구와 같이 비교적 조용한 지역과 청계천, 종로 등의 지역으로 군집화되었다.
# - cluster 2 : 관악구, 강동구, 서울숲같이 유동인구는 많지만 거주하는 인구는 상대적으로 적은 지역으로 군집화되었다.
# - cluster 3 : 공항대로, 동작대로, 정릉로, 화랑로같이 도로 위주로 군집화되었다.
# - cluster 4 : 산에 있는 측정소로 군집화되었다. 미세먼지가 제일 적고 자동차 오염이 제일 적으며, 오존 오염정도가 가장 높다는 특징을 지닌다.
# - cluster 5 : 미세먼지점수가 제일 안좋은 시흥대로, 천호대로, 한강대로로 대로변 위주로 군집화되었다.

# %% [markdown]
# ### 지도 데이터 시각화

# %%
location_1 = pd.read_excel(os.path.abspath("../프로젝트/Data")+"/station_list_도시대기.xls", skiprows=3)
location_2 = pd.read_excel(os.path.abspath("../프로젝트/Data")+"/station_list_도로변대기.xls", skiprows=3)

# %%
location = pd.concat([location_1, location_2]).reset_index(drop = True)

# %%
loc_주소 = location[['측정소명', '측정소 주소']]

# %%
loc_주소.loc[loc_주소['측정소명'] == '동작대로 중앙차로', '측정소명'] = '동작대로'
# Out:
# C:\Users\choij\AppData\Local\Temp\ipykernel_3048\1425490239.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loc_주소.loc[loc_주소['측정소명'] == '동작대로 중앙차로', '측정소명'] = '동작대로'

# %%
loc_위치 = idx_data.merge(loc_주소, how = 'left')
loc_위치=loc_위치.assign(도로명주소=np.nan)  # 도로명 주소 추가 위한 빈 column 생성

# %%
loc_위치
# Out:
#       측정소명                                         측정소 주소  도로명주소
# 0      강남구                      서울 강남구 학동로 426 강남구청 별관 1동    NaN
# 1     강남대로         서울특별시 서초구 강남대로 201 서초구민회관 앞 중앙차로 (양재동)    NaN
# 2      강동구                   서울 강동구 구천면로 42길 59 천호1동 주민센터    NaN
# 3     강변북로                       서울 성동구 강변북로 257 한강사업본부 옆    NaN
# 4      강북구                    서울 강북구 삼양로 139길 49 우이동 주민센터    NaN
# 5      강서구             서울 강서구 강서로 45 다길 71 화곡3동 푸른들청소년도서관    NaN
# 6     공항대로              서울 강서구 마곡동 727-1091 마곡역 중앙차로정류장 옆    NaN
# 7      관악구                        서울 관악구 신림동길 14 신림동 주민센터    NaN
# 8      관악산                                            NaN    NaN
# 9      광진구                  서울특별시 광진구 광나루로 571 구의 아리수정수센터    NaN
# 10     구로구                      서울 구로구 가마산로 27길 45 구로고등학교    NaN
# 11      궁동                                            NaN    NaN
# 12     금천구                     서울 금천구 금하로21길 20 시흥5동 주민센터    NaN
# 13      남산                                            NaN    NaN
# 14     노원구  서울 노원구 상계로 118 상계2동 주민센터 (23길 17 노원구 원터행복발전소)    NaN
# 15     도봉구                    서울 도봉구 시루봉로2길 34 쌍문동청소년문화의집    NaN
# 16    도산대로                      서울 강남구 도산대로 104 신사역2번출구 앞    NaN
# 17    동대문구                      서울 동대문구 천호대로13길 43 용두초등학교    NaN
# 18     동작구                     서울 동작구 사당로16아길 6 사당4동 주민센터    NaN
# 19    동작대로                  서울 동작구 사당2동 739 이수역 북단 버스중앙차로    NaN
# 20     마포구                   서울 마포구 포은로 6길 10 망원1동주민센터 옥상    NaN
# 21  마포아트센터                                            NaN    NaN
# 22     북한산                                            NaN    NaN
# 23    서대문구                  서울 서대문구 세검정로4길 32(홍제3동 주민센터)     NaN
# 24     서울숲                                            NaN    NaN
# 25     서초구                   서울 서초구 신반포로15길 16 반포 2동 주민센터    NaN
# 26     성동구                     서울 성동구 뚝섬로3길 18 성수1가1동주민센터    NaN
# 27     성북구                      서울 성북구 삼양로2길 70 길음2동 주민센터    NaN
# 28      세곡                                            NaN    NaN
# 29     송파구                서울 송파구 백제고분로 236 삼전동 주민센터 (삼전동)    NaN
# 30    시흥대로                    서울 금천구 독산동 996-9 한양수자인아파트 앞    NaN
# 31     신촌로                  서울 마포구 노고산동 57-62 (신촌역 7번 출구)    NaN
# 32     양천구                     서울 양천구 중앙로52길 56 신정4동 문화센터    NaN
# 33    영등포구               서울특별시 영등포구 당산로 123 영등포구청 (당산동3가)    NaN
# 34    영등포로                      서울 영등포구 영중로 37 (영등포시장사거리)    NaN
# 35   올림픽공원                                            NaN    NaN
# 36     용산구                   서울 용산구 한남대로 136 서울특별시중부기술교육원    NaN
# 37     은평구              서울 은평구 진흥로 215 (한국환경산업기술원 온실동2층 )    NaN
# 38  자연사박물관                                            NaN    NaN
# 39     정릉로                            서울 성북구 돈암동 8-164번지     NaN
# 40      종로                        서울 종로구 종로 169 (종묘주차장 앞)    NaN
# 41     종로구                 서울 종로구 종로35가길 19 종로5,6가 동 주민센터    NaN
# 42      중구                       서울 중구 덕수궁길 15 시청서소문별관 3동    NaN
# 43     중랑구                       서울 중랑구 용마산로 369 건강가정지원센터    NaN
# 44    천호대로             서울 강동구 천호대로 1151 길동사거리 강동성모요양병원 앞)    NaN
# 45    청계천로               서울 중구 청계천로 184 (청계천4가사거리 남강빌딩 앞)    NaN
# 46    한강대로                        서울 용산구 한강대로 405 (서울역 앞)    NaN
# 47      항동                                            NaN    NaN
# 48      행주                                            NaN    NaN
# 49     홍릉로            서울 동대문구 홍릉로 1 (청량리전철역 사거리 SC제일은행 앞)    NaN
# 50     화랑로                     서울 노원구 화랑로 429 태능입구역 8번 출구    NaN

# %%
# #측정소 주소 및 도로명 주소 기입 Program

# for i in loc_위치['측정소명']:
#     print(i,'측정소 주소는 = ', loc_위치.loc[loc_위치['측정소명'] == i, '측정소 주소'])
#     loca = input(i+'측정소 도로명 주소를 입력해주세요.')
#     loc_위치.loc[loc_위치['측정소명'] == i, '도로명주소'] = loca
# Out:
# 강남구 측정소 주소는 =  0    서울 강남구 학동로 426 강남구청 별관 1동
# Name: 측정소 주소, dtype: object
# 강남구측정소 도로명 주소를 입력해주세요.서울특별시 강남구 삼성동 16-1
# 강남대로 측정소 주소는 =  1    서울특별시 서초구 강남대로 201 서초구민회관 앞 중앙차로 (양재동)
# Name: 측정소 주소, dtype: object
# 강남대로측정소 도로명 주소를 입력해주세요.서울특별시 서초구 강남대로 201
# 강동구 측정소 주소는 =  2    서울 강동구 구천면로 42길 59 천호1동 주민센터
# Name: 측정소 주소, dtype: object
# 강동구측정소 도로명 주소를 입력해주세요.서울특별시 강동구 구천면로42길 59
# 강변북로 측정소 주소는 =  3    서울 성동구 강변북로 257 한강사업본부 옆
# Name: 측정소 주소, dtype: object
# 강변북로측정소 도로명 주소를 입력해주세요.서울특별시 성동구 강변북로 257
# 강북구 측정소 주소는 =  4    서울 강북구 삼양로 139길 49 우이동 주민센터
# Name: 측정소 주소, dtype: object
# 강북구측정소 도로명 주소를 입력해주세요.서울특별시 강북구 삼양로139길 49
# 강서구 측정소 주소는 =  5    서울 강서구 강서로 45 다길 71 화곡3동 푸른들청소년도서관
# Name: 측정소 주소, dtype: object
# 강서구측정소 도로명 주소를 입력해주세요.서울특별시 강서구 화곡동 강서로45다길 71
# 공항대로 측정소 주소는 =  6    서울 강서구 마곡동 727-1091 마곡역 중앙차로정류장 옆
# Name: 측정소 주소, dtype: object
# 공항대로측정소 도로명 주소를 입력해주세요.서울특별시 마곡역
# 관악구 측정소 주소는 =  7    서울 관악구 신림동길 14 신림동 주민센터
# Name: 측정소 주소, dtype: object
# 관악구측정소 도로명 주소를 입력해주세요.서울특별시 관악구 신림동길 14
# 관악산 측정소 주소는 =  8    NaN
# Name: 측정소 주소, dtype: object
# 관악산측정소 도로명 주소를 입력해주세요.
# 광진구 측정소 주소는 =  9    서울특별시 광진구 광나루로 571 구의 아리수정수센터
# Name: 측정소 주소, dtype: object
# 광진구측정소 도로명 주소를 입력해주세요.서울특별시 광진구 구의동 광나루로 571
# 구로구 측정소 주소는 =  10    서울 구로구 가마산로 27길 45 구로고등학교
# Name: 측정소 주소, dtype: object
# 구로구측정소 도로명 주소를 입력해주세요.서울특별시 구로구 가마산로27길 45
# 궁동 측정소 주소는 =  11    NaN
# Name: 측정소 주소, dtype: object
# 궁동측정소 도로명 주소를 입력해주세요.경기 부천시 소사구 경인옛로 73소사어울마당
# 금천구 측정소 주소는 =  12    서울 금천구 금하로21길 20 시흥5동 주민센터
# Name: 측정소 주소, dtype: object
# 금천구측정소 도로명 주소를 입력해주세요.서울특별시 금천구 금하로24길 6
# 남산 측정소 주소는 =  13    NaN
# Name: 측정소 주소, dtype: object
# 남산측정소 도로명 주소를 입력해주세요.서울특별시 용산구 남산공원길 105
# 노원구 측정소 주소는 =  14    서울 노원구 상계로 118 상계2동 주민센터 (23길 17 노원구 원터행복발전소)
# Name: 측정소 주소, dtype: object
# 노원구측정소 도로명 주소를 입력해주세요.서울특별시 노원구 상계2동 상계로23길 17
# 도봉구 측정소 주소는 =  15    서울 도봉구 시루봉로2길 34 쌍문동청소년문화의집
# Name: 측정소 주소, dtype: object
# 도봉구측정소 도로명 주소를 입력해주세요.서울특별시 도봉구 시루봉로2길 34
# 도산대로 측정소 주소는 =  16    서울 강남구 도산대로 104 신사역2번출구 앞
# Name: 측정소 주소, dtype: object
# 도산대로측정소 도로명 주소를 입력해주세요.서울특별시 강남구 신사동 610-2
# 동대문구 측정소 주소는 =  17    서울 동대문구 천호대로13길 43 용두초등학교
# Name: 측정소 주소, dtype: object
# 동대문구측정소 도로명 주소를 입력해주세요.서울특별시 동대문구 용신동 천호대로13길 43
# 동작구 측정소 주소는 =  18    서울 동작구 사당로16아길 6 사당4동 주민센터
# Name: 측정소 주소, dtype: object
# 동작구측정소 도로명 주소를 입력해주세요.서울특별시 동작구 사당로16아길 6
# 동작대로 측정소 주소는 =  19    서울 동작구 사당2동 739 이수역 북단 버스중앙차로
# Name: 측정소 주소, dtype: object
# 동작대로측정소 도로명 주소를 입력해주세요.서울특별시 동작구 사당로 310
# 마포구 측정소 주소는 =  20    서울 마포구 포은로 6길 10 망원1동주민센터 옥상
# Name: 측정소 주소, dtype: object
# 마포구측정소 도로명 주소를 입력해주세요.서울특별시 마포구 포은로6길 10
# 마포아트센터 측정소 주소는 =  21    NaN
# Name: 측정소 주소, dtype: object
# 마포아트센터측정소 도로명 주소를 입력해주세요.마포구 대흥로20길 28(마포아트센터)
# 북한산 측정소 주소는 =  22    NaN
# Name: 측정소 주소, dtype: object
# 북한산측정소 도로명 주소를 입력해주세요.강북구 삼양로 181길 387 (우이령 전경대 위)
# 서대문구 측정소 주소는 =  23    서울 서대문구 세검정로4길 32(홍제3동 주민센터)
# Name: 측정소 주소, dtype: object
# 서대문구측정소 도로명 주소를 입력해주세요.서울특별시 서대문구 세검정로4길 32
# 서울숲 측정소 주소는 =  24    NaN
# Name: 측정소 주소, dtype: object
# 서울숲측정소 도로명 주소를 입력해주세요.성동구 뚝섬로 273(서울숲 방문자센터 옆)
# 서초구 측정소 주소는 =  25    서울 서초구 신반포로15길 16 반포 2동 주민센터
# Name: 측정소 주소, dtype: object
# 서초구측정소 도로명 주소를 입력해주세요.서울특별시 서초구 신반포로15길 16
# 성동구 측정소 주소는 =  26    서울 성동구 뚝섬로3길 18 성수1가1동주민센터
# Name: 측정소 주소, dtype: object
# 성동구측정소 도로명 주소를 입력해주세요.서울특별시 성동구 뚝섬로3길 18
# 성북구 측정소 주소는 =  27    서울 성북구 삼양로2길 70 길음2동 주민센터
# Name: 측정소 주소, dtype: object
# 성북구측정소 도로명 주소를 입력해주세요.서울특별시 성북구 삼양로2길 70
# 세곡 측정소 주소는 =  28    NaN
# Name: 측정소 주소, dtype: object
# 세곡측정소 도로명 주소를 입력해주세요.강남구 밤고개로 337 (세곡사거리)
# 송파구 측정소 주소는 =  29    서울 송파구 백제고분로 236 삼전동 주민센터 (삼전동)
# Name: 측정소 주소, dtype: object
# 송파구측정소 도로명 주소를 입력해주세요.서울특별시 송파구 백제고분로 236
# 시흥대로 측정소 주소는 =  30    서울 금천구 독산동 996-9 한양수자인아파트 앞
# Name: 측정소 주소, dtype: object
# 시흥대로측정소 도로명 주소를 입력해주세요.서울특별시 금천구 독산동 968
# 신촌로 측정소 주소는 =  31    서울 마포구 노고산동 57-62 (신촌역 7번 출구)
# Name: 측정소 주소, dtype: object
# 신촌로측정소 도로명 주소를 입력해주세요.서울 마포구 노고산동 57-62 (신촌역 7번 출구)
# 양천구 측정소 주소는 =  32    서울 양천구 중앙로52길 56 신정4동 문화센터
# Name: 측정소 주소, dtype: object
# 양천구측정소 도로명 주소를 입력해주세요.서울 양천구 중앙로52길 56
# 영등포구 측정소 주소는 =  33    서울특별시 영등포구 당산로 123 영등포구청 (당산동3가)
# Name: 측정소 주소, dtype: object
# 영등포구측정소 도로명 주소를 입력해주세요.서울특별시 영등포구 당산동3가 당산로 123
# 영등포로 측정소 주소는 =  34    서울 영등포구 영중로 37 (영등포시장사거리)
# Name: 측정소 주소, dtype: object
# 영등포로측정소 도로명 주소를 입력해주세요.서울 영등포구 영중로 37
# 올림픽공원 측정소 주소는 =  35    NaN
# Name: 측정소 주소, dtype: object
# 올림픽공원측정소 도로명 주소를 입력해주세요.송파구 올림픽로 424(서울역사편찬원)
# 용산구 측정소 주소는 =  36    서울 용산구 한남대로 136 서울특별시중부기술교육원
# Name: 측정소 주소, dtype: object
# 용산구측정소 도로명 주소를 입력해주세요.서울특별시 용산구 한남대로 136
# 은평구 측정소 주소는 =  37    서울 은평구 진흥로 215 (한국환경산업기술원 온실동2층 )
# Name: 측정소 주소, dtype: object
# 은평구측정소 도로명 주소를 입력해주세요.서울특별시 은평구 진흥로 215
# 자연사박물관 측정소 주소는 =  38    NaN
# Name: 측정소 주소, dtype: object
# 자연사박물관측정소 도로명 주소를 입력해주세요.서대문구 연희로32길 51(서대문자연사박물관)
# 정릉로 측정소 주소는 =  39    서울 성북구 돈암동 8-164번지
# Name: 측정소 주소, dtype: object
# 정릉로측정소 도로명 주소를 입력해주세요.서울특별시 성북구 돈암동 8-164
# 종로 측정소 주소는 =  40    서울 종로구 종로 169 (종묘주차장 앞)
# Name: 측정소 주소, dtype: object
# 종로측정소 도로명 주소를 입력해주세요.서울특별시 종로구 종로 157
# 종로구 측정소 주소는 =  41    서울 종로구 종로35가길 19 종로5,6가 동 주민센터
# Name: 측정소 주소, dtype: object
# 종로구측정소 도로명 주소를 입력해주세요.서울특별시 종로구 종로35가길 19
# 중구 측정소 주소는 =  42    서울 중구 덕수궁길 15 시청서소문별관 3동
# Name: 측정소 주소, dtype: object
# 중구측정소 도로명 주소를 입력해주세요.서울특별시 중구 덕수궁길 15
# 중랑구 측정소 주소는 =  43    서울 중랑구 용마산로 369 건강가정지원센터
# Name: 측정소 주소, dtype: object
# 중랑구측정소 도로명 주소를 입력해주세요.서울특별시 중랑구 용마산로 369
# 천호대로 측정소 주소는 =  44    서울 강동구 천호대로 1151 길동사거리 강동성모요양병원 앞)
# Name: 측정소 주소, dtype: object
# 천호대로측정소 도로명 주소를 입력해주세요.서울특별시 강동구 천호대로 1151
# 청계천로 측정소 주소는 =  45    서울 중구 청계천로 184 (청계천4가사거리 남강빌딩 앞)
# Name: 측정소 주소, dtype: object
# 청계천로측정소 도로명 주소를 입력해주세요.서울특별시 중구 청계천로 184
# 한강대로 측정소 주소는 =  46    서울 용산구 한강대로 405 (서울역 앞)
# Name: 측정소 주소, dtype: object
# 한강대로측정소 도로명 주소를 입력해주세요.서울 용산구 한강대로 405
# 항동 측정소 주소는 =  47    NaN
# Name: 측정소 주소, dtype: object
# 항동측정소 도로명 주소를 입력해주세요.구로구 연동로 240
# 행주 측정소 주소는 =  48    NaN
# Name: 측정소 주소, dtype: object
# 행주측정소 도로명 주소를 입력해주세요.김포시 고촌읍 은행영사정로 197
# 홍릉로 측정소 주소는 =  49    서울 동대문구 홍릉로 1 (청량리전철역 사거리 SC제일은행 앞)
# Name: 측정소 주소, dtype: object
# 홍릉로측정소 도로명 주소를 입력해주세요.서울 동대문구 홍릉로 1
# 화랑로 측정소 주소는 =  50    서울 노원구 화랑로 429 태능입구역 8번 출구
# Name: 측정소 주소, dtype: object
# 화랑로측정소 도로명 주소를 입력해주세요.서울 노원구 화랑로 429

# %%
loc_위치.loc[loc_위치['측정소명'] == '관악산', '도로명주소'] = '과천시 자하동길 64'

# %%
loc_위치['도로명주소'].isnull().sum()
# Out:
# 50

# %% [markdown]
# ***
# #### ***여기서 부터는 데이터 생성 과정이여서 아래에 있는 data폴더에서 읽어들이는 부분만 돌리면 됩니다.***
# ***

# %% [markdown]
# ### ***위도 경도 반환***

# %%
#!pip install geopy

# %%
####### 도로명주소 위도 경도 값으로 바꿔주기 ########
from geopy.geocoders import Nominatim
geo_local = Nominatim(user_agent='South Korea')

# 위도, 경도 반환하는 함수
def geocoding(address):
    try:
        geo = geo_local.geocode(address)
        x_y = [geo.latitude, geo.longitude]
        return x_y

    except:
        return [0,0]

# %%
address = loc_위치['도로명주소']

# %%
#####주소를 위,경도 값으로 변환하기 #####
latitude = []
longitude =[]

for i in address:
    latitude.append(geocoding(i)[0])
    longitude.append(geocoding(i)[1])

# %%
#####Dataframe만들기######
address_df = pd.DataFrame({'측정소명': loc_위치['측정소명'],'주소':address,'위도':latitude,'경도':longitude})

# %%
address_df[address_df['위도'] == 0]
# Out:
#       측정소명                             주소   위도   경도
# 8      관악산                    과천시 자하동길 64  0.0  0.0
# 11      궁동       경기 부천시 소사구 경인옛로 73소사어울마당  0.0  0.0
# 15     도봉구            서울특별시 도봉구 시루봉로2길 34  0.0  0.0
# 21  마포아트센터          마포구 대흥로20길 28(마포아트센터)  0.0  0.0
# 22     북한산   강북구 삼양로 181길 387 (우이령 전경대 위)  0.0  0.0
# 24     서울숲       성동구 뚝섬로 273(서울숲 방문자센터 옆)  0.0  0.0
# 28      세곡           강남구 밤고개로 337 (세곡사거리)  0.0  0.0
# 30    시흥대로              서울특별시 금천구 독산동 968  0.0  0.0
# 31     신촌로  서울 마포구 노고산동 57-62 (신촌역 7번 출구)  0.0  0.0
# 35   올림픽공원          송파구 올림픽로 424(서울역사편찬원)  0.0  0.0
# 38  자연사박물관      서대문구 연희로32길 51(서대문자연사박물관)  0.0  0.0

# %%
address_df.loc[address_df['측정소명'] == '관악산', '위도'] = 37.4432
address_df.loc[address_df['측정소명'] == '관악산', '경도'] = 126.9673

# %%
address_df.loc[address_df['측정소명'] == '궁동', '위도'] = 37.48
address_df.loc[address_df['측정소명'] == '궁동', '경도'] = 126.7999

# %%
address_df.loc[address_df['측정소명'] == '도봉구', '위도'] = 37.6541
address_df.loc[address_df['측정소명'] == '도봉구', '경도'] = 127.0291

# %%
address_df.loc[address_df['측정소명'] == '마포아트센터', '위도'] = 37.5497
address_df.loc[address_df['측정소명'] == '마포아트센터', '경도'] = 126.9456

# %%
address_df.loc[address_df['측정소명'] == '북한산', '위도'] = 37.6789
address_df.loc[address_df['측정소명'] == '북한산', '경도'] = 127.0023

# %%
address_df.loc[address_df['측정소명'] == '서울숲', '위도'] = 37.5429
address_df.loc[address_df['측정소명'] == '서울숲', '경도'] = 127.0417

# %%
address_df.loc[address_df['측정소명'] == '세곡', '위도'] = 37.464
address_df.loc[address_df['측정소명'] == '세곡', '경도'] = 127.109

# %%
address_df.loc[address_df['측정소명'] == '시흥대로', '위도'] = 37.4754
address_df.loc[address_df['측정소명'] == '시흥대로', '경도'] = 126.8993

# %%
address_df.loc[address_df['측정소명'] == '신촌로', '위도'] = 37.5549
address_df.loc[address_df['측정소명'] == '신촌로', '경도'] = 126.9362

# %%
address_df.loc[address_df['측정소명'] == '올림픽공원', '위도'] = 37.5217
address_df.loc[address_df['측정소명'] == '올림픽공원', '경도'] = 127.1244

# %%
address_df.loc[address_df['측정소명'] == '자연사박물관', '위도'] = 37.5767
address_df.loc[address_df['측정소명'] == '자연사박물관', '경도'] = 126.9378

# %%
# 위 분석에서 제외했던 항동, 궁동 제거
address_df = address_df[address_df['측정소명'] != '항동']
address_df = address_df[address_df['측정소명'] != '궁동']

# %%
# df 저장

# %%
address_df.to_csv('address_df.csv', encoding = 'cp949', index = False)

# %% [markdown]
# ***
# ***

# %%
address_df = pd.read_csv(os.path.abspath("../프로젝트/Data")+"/address_df.csv" , encoding = 'cp949')

# %%
address_df = address_df.reset_index(drop = True)

# %%
address_df = pd.concat([address_df, 분석_data.reset_index()[['cluster']]], axis = 1)

# %% [markdown]
# ### ***folium 패키지를 이용한 시각화***

# %%
# !pip install folium

# %%
import folium
from folium import FeatureGroup, LayerControl, Map, Marker

# %%
# map 출발지점은 국민대학교 위치로 설정

# 위도
국민대_latitude = 37.6109
# 경도
국민대_longitude = 126.9973

# %%
m = folium.Map(location=[국민대_latitude, 국민대_longitude],
               zoom_start=17
              )

# %% [markdown]
# ### 군집화 결과 분석
# - cluster 0 : 비교적 최근 교통량이 적고, 강남구, 광진구, 마포구, 서대문구, 은평구 등으로 군집화되었다.
# - cluster 1 : 강북구, 강서구와 같이 비교적 조용한 지역과 청계천, 종로 등의 지역으로 군집화되었다.
# - cluster 2 : 관악구, 강동구, 서울숲같이 유동인구는 많지만 거주하는 인구는 상대적으로 적은 지역으로 군집화되었다.
# - cluster 3 : 공항대로, 동작대로, 정릉로, 화랑로같이 도로 위주로 군집화되었다.
# - cluster 4 : 산에 있는 측정소로 군집화되었다. 미세먼지가 제일 적고 자동차 오염이 제일 적으며, 오존 오염정도가 가장 높다는 특징을 지닌다.
# - cluster 5 : 미세먼지점수가 제일 안좋은 시흥대로, 천호대로, 한강대로로 대로변 위주로 군집화되었다.

# %%
# 그룹만들기
g0 = FeatureGroup(name = 'cluster 0')
g1 = FeatureGroup(name = 'cluster 1')
g2 = FeatureGroup(name = 'cluster 2')
g3 = FeatureGroup(name = 'cluster 3')
g4 = FeatureGroup(name = 'cluster 4')
g5 = FeatureGroup(name = 'cluster 5')

# %%
# address에 있는 좌표 하나씩 해당 cluster group에 찍기
for row in address_df.itertuples():
    idx, 측정소명, 주소, latitude, longitude, cluster = row
    
    if cluster == 0:  # 비교적 최근 교통량이 적음.
        folium.Marker([latitude, longitude], popup=측정소명,
           icon=folium.Icon(
               color='darkblue',
               icon='landmark',
               prefix='fa'
               )).add_to(g0)
        
    elif cluster == 1:  # 비교적 조용한 지역과 청계천, 종로 등의 지역.
        folium.Marker([latitude, longitude], popup=측정소명,
           icon=folium.Icon(
               color='purple',
               icon='user',
               prefix='fa'
               )).add_to(g1)
    
    elif cluster == 2:  # 유동인구는 많지만 거주하는 인구는 상대적으로 적은 지역으로 군집화되었다.
        folium.Marker([latitude, longitude], popup=측정소명,
           icon=folium.Icon(
               color='darkred',
               icon='building-user',
               prefix='fa'
               )).add_to(g2)
        
    elif cluster == 3:  # 공항대로, 동작대로, 정릉로, 화랑로같이 도로 위주로 군집화되었다.
        folium.Marker([latitude, longitude], popup=측정소명,
           icon=folium.Icon(
               color='cadetblue',
               icon='car-side',
               prefix='fa'
               )).add_to(g3)
        
    elif cluster == 4:  # 산에 있는 측정소
        folium.Marker([latitude, longitude], popup=측정소명,
           icon=folium.Icon(
               color='green',
               icon='mountain-sun',
               prefix='fa'
               )).add_to(g4)
                      
    elif cluster == 5:  # 시흥대로, 천호대로, 한강대로로 대로변 위주
        folium.Marker([latitude, longitude], popup=측정소명,
           icon=folium.Icon(
               color='black',
               icon='road',
               prefix='fa'
               )).add_to(g5)
    
g0.add_to(m)
g1.add_to(m)
g2.add_to(m)
g3.add_to(m)
g4.add_to(m)
g5.add_to(m)

LayerControl(collapsed=False).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_27b45f49ea2e54295c5502384875b97a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_27b45f49ea2e54295c5502384875b97a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_27b45f49ea2e54295c5502384875b97a = L.map(
#                 &quot;map_27b45f49ea2e54295c5502384875b97a&quot;,
#                 {
#                     center: [37.6109, 126.9973],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7a4649a422f94c2cfe746206faf93c9d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_27b45f49ea2e54295c5502384875b97a);
#
#
#             var feature_group_2278d50856875613b165df4d3ff38311 = L.featureGroup(
#                 {}
#             ).addTo(map_27b45f49ea2e54295c5502384875b97a);
#
#
#             var marker_9cdceb5e2d1e94b00416c5c0d05beb4a = L.marker(
#                 [37.5137422, 127.05544630232768],
#                 {}
#             ).addTo(feature_group_2278d50856875613b165df4d3ff38311);
#
#
#             var icon_818fcb3a2c512b77a56b0b8e168824f3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;landmark&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_9cdceb5e2d1e94b00416c5c0d05beb4a.setIcon(icon_818fcb3a2c512b77a56b0b8e168824f3);
#
#
#         var popup_795bb057e39896bb7846353c85b1f817 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8bf3be1ddd383f84396fad9bbe84dfc3 = $(`&lt;div id=&quot;html_8bf3be1ddd383f84396fad9bbe84dfc3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강남구&lt;/div&gt;`)[0];
#                 popup_795bb057e39896bb7846353c85b1f817.setContent(html_8bf3be1ddd383f84396fad9bbe84dfc3);
#
#
#
#         marker_9cdceb5e2d1e94b00416c5c0d05beb4a.bindPopup(popup_795bb057e39896bb7846353c85b1f817)
#         ;
#
#
#
#
#             var marker_c6eff8bdbee9ea5d750e4029885ff595 = L.marker(
#                 [37.54504585, 127.09445790724516],
#                 {}
#             ).addTo(feature_group_2278d50856875613b165df4d3ff38311);
#
#
#             var icon_8a56b78aa9ee0c0343190ed753f52483 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;landmark&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_c6eff8bdbee9ea5d750e4029885ff595.setIcon(icon_8a56b78aa9ee0c0343190ed753f52483);
#
#
#         var popup_4e2be0a8fd334d6558ddbd13c5d72c4c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e63fda2ed9700ae481e1e0cdf99a3ae6 = $(`&lt;div id=&quot;html_e63fda2ed9700ae481e1e0cdf99a3ae6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;광진구&lt;/div&gt;`)[0];
#                 popup_4e2be0a8fd334d6558ddbd13c5d72c4c.setContent(html_e63fda2ed9700ae481e1e0cdf99a3ae6);
#
#
#
#         marker_c6eff8bdbee9ea5d750e4029885ff595.bindPopup(popup_4e2be0a8fd334d6558ddbd13c5d72c4c)
#         ;
#
#
#
#
#             var marker_42536d8a569afe79adf12fb43e54a6a6 = L.marker(
#                 [37.6541, 127.0291],
#                 {}
#             ).addTo(feature_group_2278d50856875613b165df4d3ff38311);
#
#
#             var icon_1d45f0db8c3def5838f79124cf66e563 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;landmark&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_42536d8a569afe79adf12fb43e54a6a6.setIcon(icon_1d45f0db8c3def5838f79124cf66e563);
#
#
#         var popup_c8dc6375d2c105b47bf875e82bba8f81 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_68c61b2c4bb353cfec110e872cec01a6 = $(`&lt;div id=&quot;html_68c61b2c4bb353cfec110e872cec01a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;도봉구&lt;/div&gt;`)[0];
#                 popup_c8dc6375d2c105b47bf875e82bba8f81.setContent(html_68c61b2c4bb353cfec110e872cec01a6);
#
#
#
#         marker_42536d8a569afe79adf12fb43e54a6a6.bindPopup(popup_c8dc6375d2c105b47bf875e82bba8f81)
#         ;
#
#
#
#
#             var marker_dd859378684d0f412cfccbe0c42772e9 = L.marker(
#                 [37.5558809, 126.9062727],
#                 {}
#             ).addTo(feature_group_2278d50856875613b165df4d3ff38311)

# %% [markdown]
# cluster 0 = 올림픽공원, 마포아트센터, 강남구, 자연사박물관등이 포진 -> landmark icon 생성
# cluster 1 = 비교적 조용한 지역과 청계천, 종로 등의 지역 -> 그냥 사람 사는데라 생각해서 user icon 생성
# cluster 2 = 유동인구는 많지만 거주하는 인구는 상대적으로 적은 지역 -> 회사들이 많은 곳으로 생각 building icon 생성
# cluster 3 = 공항대로, 동작대로, 정릉로, 화랑로같이 도로 위주 -> 차가 많은 곳 car icon 생성
# cluster 4 = 산에 있는 측정소 -> mountain icon 생성
# cluster 5 = 시흥대로, 천호대로, 한강대로로 대로변 위주 -> road icon 생성

# %%
# map 출발지점은 국민대학교 위치로 설정

# 위도
국민대_latitude = 37.6109
# 경도
국민대_longitude = 126.9973

m = folium.Map(location=[국민대_latitude, 국민대_longitude], tiles='Stamen Toner',
               zoom_start=17)

# 그룹만들기
g0 = FeatureGroup(name = 'cluster 0')
g1 = FeatureGroup(name = 'cluster 1')
g2 = FeatureGroup(name = 'cluster 2')
g3 = FeatureGroup(name = 'cluster 3')
g4 = FeatureGroup(name = 'cluster 4')
g5 = FeatureGroup(name = 'cluster 5')

# address에 있는 좌표 하나씩 해당 cluster group에 찍기
for row in address_df.itertuples():
    idx, 측정소명, 주소, latitude, longitude, cluster = row
    
    if cluster == 0:  # 비교적 최근 교통량이 적음.
        folium.Marker([latitude, longitude], popup=측정소명,
           icon=folium.Icon(
               color='darkblue',
               icon='landmark',
               prefix='fa'
               )).add_to(g0)
        
    elif cluster == 1:  # 비교적 조용한 지역과 청계천, 종로 등의 지역.
        folium.Marker([latitude, longitude], popup=측정소명,
           icon=folium.Icon(
               color='purple',
               icon='user',
               prefix='fa'
               )).add_to(g1)
    
    elif cluster == 2:  # 유동인구는 많지만 거주하는 인구는 상대적으로 적은 지역으로 군집화되었다.
        folium.Marker([latitude, longitude], popup=측정소명,
           icon=folium.Icon(
               color='darkred',
               icon='building-user',
               prefix='fa'
               )).add_to(g2)
        
    elif cluster == 3:  # 공항대로, 동작대로, 정릉로, 화랑로같이 도로 위주로 군집화되었다.
        folium.Marker([latitude, longitude], popup=측정소명,
           icon=folium.Icon(
               color='cadetblue',
               icon='car-side',
               prefix='fa'
               )).add_to(g3)
        
    elif cluster == 4:  # 산에 있는 측정소
        folium.Marker([latitude, longitude], popup=측정소명,
           icon=folium.Icon(
               color='green',
               icon='mountain-sun',
               prefix='fa'
               )).add_to(g4)
                      
    elif cluster == 5:  # 시흥대로, 천호대로, 한강대로로 대로변 위주
        folium.Marker([latitude, longitude], popup=측정소명,
           icon=folium.Icon(
               color='black',
               icon='road',
               prefix='fa'
               )).add_to(g5)
    
g0.add_to(m)
g1.add_to(m)
g2.add_to(m)
g3.add_to(m)
g4.add_to(m)
g5.add_to(m)

LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6f8829c4004c751929d90af141826769 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6f8829c4004c751929d90af141826769&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6f8829c4004c751929d90af141826769 = L.map(
#                 &quot;map_6f8829c4004c751929d90af141826769&quot;,
#                 {
#                     center: [37.6109, 126.9973],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c9fb195fd15f63090a37a65e876f0efc = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6f8829c4004c751929d90af141826769);
#
#
#             var feature_group_546e0ef0aa7efd35f812f2aac91bf87f = L.featureGroup(
#                 {}
#             ).addTo(map_6f8829c4004c751929d90af141826769);
#
#
#             var marker_6f768bc4e6c8b90e636f98fb92e8b39b = L.marker(
#                 [37.5137422, 127.05544630232768],
#                 {}
#             ).addTo(feature_group_546e0ef0aa7efd35f812f2aac91bf87f);
#
#
#             var icon_39c01f29f1980b7555b3fb4cfbdefefe = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;landmark&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_6f768bc4e6c8b90e636f98fb92e8b39b.setIcon(icon_39c01f29f1980b7555b3fb4cfbdefefe);
#
#
#         var popup_52db8dc0423ef3e6972cfef89d25d071 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_26c5d8ab29cabb77c7ab8e784f8be85d = $(`&lt;div id=&quot;html_26c5d8ab29cabb77c7ab8e784f8be85d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강남구&lt;/div&gt;`)[0];
#                 popup_52db8dc0423ef3e6972cfef89d25d071.setContent(html_26c5d8ab29cabb77c7ab8e784f8be85d);
#
#
#
#         marker_6f768bc4e6c8b90e636f98fb92e8b39b.bindPopup(popup_52db8dc0423ef3e6972cfef89d25d071)
#         ;
#
#
#
#
#             var marker_1bba67859afb0b4abaf5b64b71f1e496 = L.marker(
#                 [37.54504585, 127.09445790724516],
#                 {}
#             ).addTo(feature_group_546e0ef0aa7efd35f812f2aac91bf87f);
#
#
#             var icon_b6ff29cc385370cc197e76ee123a35b8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;landmark&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_1bba67859afb0b4abaf5b64b71f1e496.setIcon(icon_b6ff29cc385370cc197e76ee123a35b8);
#
#
#         var popup_79606c1028f2245d4ae1323134c1b335 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_944e664fb7f295a868526968d37c945d = $(`&lt;div id=&quot;html_944e664fb7f295a868526968d37c945d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;광진구&lt;/div&gt;`)[0];
#                 popup_79606c1028f2245d4ae1323134c1b335.setContent(html_944e664fb7f295a868526968d37c945d);
#
#
#
#         marker_1bba67859afb0b4abaf5b64b71f1e496.bindPopup(popup_79606c1028f2245d4ae1323134c1b335)
#         ;
#
#
#
#
#             var marker_22270e1860df0cc12d1c0fb82fef2188 = L.marker(
#                 [37.6541, 127.0291],
#                 {}
#             ).addTo(feature_group_546e0ef0aa7efd35f812f2aac91bf87f);
#
#
#             var icon_f5ab14d6c8552baf39dcd0756a9a59c6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;landmark&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_22270e1860df0cc12d1c0fb82fef2188.setIcon(icon_f5ab14d6c8552baf39dcd0756a9a59c6);
#
#
#         var popup_caaa12455866e045a3fe6672f6d0b269 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b38aa94e98d0bf9412844e286fe2f9d6 = $(`&lt;div id=&quot;html_b38aa94e98d0bf9412844e286fe2f9d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;도봉구&lt;/div&gt;`)[0];
#                 popup_caaa12455866e045a3fe6672f6d0b269.setContent(html_b38aa94e98d0bf9412844e286fe2f9d6);
#
#
#
#         marker_22270e1860df0cc12d1c0fb82fef2188.bindPopup(
